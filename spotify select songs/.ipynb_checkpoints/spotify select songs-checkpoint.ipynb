# %%
import pandas as pd

# %%
import json

# %%
import requests

# %%
with open("vetting_playlist.json", "r") as file:
    data = json.load(file)

# %%
data["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
data['tracks']['items'][0]
# Out:
# {'added_at': '2017-06-23T23:21:59Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#   'href': 'https://api.spotify.com/v1/users/1225630715',
#   'id': '1225630715',
#   'type': 'user',
#   'uri': 'spotify:user:1225630715'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': [],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': [],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/6SIib5yrq0saKy08p2IPrB',
#    'id': '6SIib5yrq0saKy08p2IPrB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c48375f67f100f88207b54bc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c48375f67f100f88207b54bc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c48375f67f100f88207b54bc',
#      'width': 64}],
#    'name': 'Bad Self Portraits',
#    'release_date': '2014-02-18',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:6SIib5yrq0saKy08p2IPrB',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#      'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#      'id': '3nuc29fYGlQbIrwh4yrNWd',
#      'name': 'Lake Street Dive',
#      'type': 'artist',
#      'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6SIib5yrq0saKy08p2IPrB'},
#    'total_tracks': 11},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#     'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#     'id': '3nuc29fYGlQbIrwh4yrNWd',
#     'name': 'Lake Street Dive',
#     'type': 'artist',
#     'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#   'disc_number': 1,
#   'track_number': 3,
#   'duration_ms': 215879,
#   'external_ids': {'isrc': 'USFMT1406103'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0NSEZeWHkYCknk1nAVO1Fh'},
#   'href': 'https://api.spotify.com/v1/tracks/0NSEZeWHkYCknk1nAVO1Fh',
#   'id': '0NSEZeWHkYCknk1nAVO1Fh',
#   'name': 'Better Than',
#   'popularity': 0,
#   'uri': 'spotify:track:0NSEZeWHkYCknk1nAVO1Fh',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
data['tracks']['items']
# Out:
# [{'added_at': '2017-06-23T23:21:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6SIib5yrq0saKy08p2IPrB',
#     'id': '6SIib5yrq0saKy08p2IPrB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c48375f67f100f88207b54bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c48375f67f100f88207b54bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c48375f67f100f88207b54bc',
#       'width': 64}],
#     'name': 'Bad Self Portraits',
#     'release_date': '2014-02-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6SIib5yrq0saKy08p2IPrB',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#       'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#       'id': '3nuc29fYGlQbIrwh4yrNWd',
#       'name': 'Lake Street Dive',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6SIib5yrq0saKy08p2IPrB'},
#     'total_tracks': 11},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#      'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#      'id': '3nuc29fYGlQbIrwh4yrNWd',
#      'name': 'Lake Street Dive',
#      'type': 'artist',
#      'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 215879,
#    'external_ids': {'isrc': 'USFMT1406103'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0NSEZeWHkYCknk1nAVO1Fh'},
#    'href': 'https://api.spotify.com/v1/tracks/0NSEZeWHkYCknk1nAVO1Fh',
#    'id': '0NSEZeWHkYCknk1nAVO1Fh',
#    'name': 'Better Than',
#    'popularity': 0,
#    'uri': 'spotify:track:0NSEZeWHkYCknk1nAVO1Fh',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-21T17:02:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/4g4iUbyDPTz3wCy25Tvivk',
#     'id': '4g4iUbyDPTz3wCy25Tvivk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737a75155128d3e79aa8a30701',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027a75155128d3e79aa8a30701',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517a75155128d3e79aa8a30701',
#       'width': 64}],
#     'name': 'Arrow',
#     'release_date': '2012-02-14',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4g4iUbyDPTz3wCy25Tvivk',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wwMTLM2da1sa2JcJslf8W'},
#       'href': 'https://api.spotify.com/v1/artists/2wwMTLM2da1sa2JcJslf8W',
#       'id': '2wwMTLM2da1sa2JcJslf8W',
#       'name': 'Heartless Bastards',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wwMTLM2da1sa2JcJslf8W'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4g4iUbyDPTz3wCy25Tvivk'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wwMTLM2da1sa2JcJslf8W'},
#      'href': 'https://api.spotify.com/v1/artists/2wwMTLM2da1sa2JcJslf8W',
#      'id': '2wwMTLM2da1sa2JcJslf8W',
#      'name': 'Heartless Bastards',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wwMTLM2da1sa2JcJslf8W'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 308066,
#    'external_ids': {'isrc': 'USBQU1100085'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/17ZnveSDBpG9QtL7zLJNPy'},
#    'href': 'https://api.spotify.com/v1/tracks/17ZnveSDBpG9QtL7zLJNPy',
#    'id': '17ZnveSDBpG9QtL7zLJNPy',
#    'name': 'Only For You',
#    'popularity': 0,
#    'uri': 'spotify:track:17ZnveSDBpG9QtL7zLJNPy',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-12T22:46:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0LyGgFrZFXpRKpgj664Xu7',
#     'id': '0LyGgFrZFXpRKpgj664Xu7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d4d231e11ce86d2a6e6f9414',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d4d231e11ce86d2a6e6f9414',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d4d231e11ce86d2a6e6f9414',
#       'width': 64}],
#     'name': 'Thrill of the Arts',
#     'release_date': '2015-10-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0LyGgFrZFXpRKpgj664Xu7',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#       'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#       'id': '7pXu47GoqSYRajmBCjxdD6',
#       'name': 'Vulfpeck',
#       'type': 'artist',
#       'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0LyGgFrZFXpRKpgj664Xu7'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#      'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#      'id': '7pXu47GoqSYRajmBCjxdD6',
#      'name': 'Vulfpeck',
#      'type': 'artist',
#      'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 181259,
#    'external_ids': {'isrc': 'TCACH1515840'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1DrlLvlYd1FIjNavRm6NdX'},
#    'href': 'https://api.spotify.com/v1/tracks/1DrlLvlYd1FIjNavRm6NdX',
#    'id': '1DrlLvlYd1FIjNavRm6NdX',
#    'name': 'Back Pocket',
#    'popularity': 61,
#    'uri': 'spotify:track:1DrlLvlYd1FIjNavRm6NdX',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:53:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 257920,
#    'external_ids': {'isrc': 'USATO1400852'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/51ggEZWbFP5dMdWjGCDYTk'},
#    'href': 'https://api.spotify.com/v1/tracks/51ggEZWbFP5dMdWjGCDYTk',
#    'id': '51ggEZWbFP5dMdWjGCDYTk',
#    'name': 'Dunes',
#    'popularity': 0,
#    'uri': 'spotify:track:51ggEZWbFP5dMdWjGCDYTk',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T23:13:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5UXWs03dk4KTJioTAqQKWv',
#     'id': '5UXWs03dk4KTJioTAqQKWv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7db380b3e3bf7080007502c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7db380b3e3bf7080007502c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7db380b3e3bf7080007502c',
#       'width': 64}],
#     'name': 'Bahamas is Afie',
#     'release_date': '2014-08-19',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5UXWs03dk4KTJioTAqQKWv',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C50EbCS11M0VbGyH3OfLt'},
#       'href': 'https://api.spotify.com/v1/artists/4C50EbCS11M0VbGyH3OfLt',
#       'id': '4C50EbCS11M0VbGyH3OfLt',
#       'name': 'Bahamas',
#       'type': 'artist',
#       'uri': 'spotify:artist:4C50EbCS11M0VbGyH3OfLt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UXWs03dk4KTJioTAqQKWv'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C50EbCS11M0VbGyH3OfLt'},
#      'href': 'https://api.spotify.com/v1/artists/4C50EbCS11M0VbGyH3OfLt',
#      'id': '4C50EbCS11M0VbGyH3OfLt',
#      'name': 'Bahamas',
#      'type': 'artist',
#      'uri': 'spotify:artist:4C50EbCS11M0VbGyH3OfLt'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 234973,
#    'external_ids': {'isrc': 'USUG11400491'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/40WXqoyOLAAugGmJWZU1FY'},
#    'href': 'https://api.spotify.com/v1/tracks/40WXqoyOLAAugGmJWZU1FY',
#    'id': '40WXqoyOLAAugGmJWZU1FY',
#    'name': 'All The Time',
#    'popularity': 18,
#    'uri': 'spotify:track:40WXqoyOLAAugGmJWZU1FY',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:54:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1dNRrt0QTrQrZnujD7KS4k',
#     'id': '1dNRrt0QTrQrZnujD7KS4k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273101b0c82d0d3d9079b5b3966',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02101b0c82d0d3d9079b5b3966',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851101b0c82d0d3d9079b5b3966',
#       'width': 64}],
#     'name': 'Future People',
#     'release_date': '2015-03-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1dNRrt0QTrQrZnujD7KS4k',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1dNRrt0QTrQrZnujD7KS4k'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 201612,
#    'external_ids': {'isrc': 'USATO1400853'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6p5LBZkLRIeVhbLh0w7EuP'},
#    'href': 'https://api.spotify.com/v1/tracks/6p5LBZkLRIeVhbLh0w7EuP',
#    'id': '6p5LBZkLRIeVhbLh0w7EuP',
#    'name': 'Future People',
#    'popularity': 0,
#    'uri': 'spotify:track:6p5LBZkLRIeVhbLh0w7EuP',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:55:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 232546,
#    'external_ids': {'isrc': 'USATO1400851'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2lrRWbiHPdBicufAqrGN3r'},
#    'href': 'https://api.spotify.com/v1/tracks/2lrRWbiHPdBicufAqrGN3r',
#    'id': '2lrRWbiHPdBicufAqrGN3r',
#    'name': "Don't Wanna Fight",
#    'popularity': 0,
#    'uri': 'spotify:track:2lrRWbiHPdBicufAqrGN3r',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:58:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 5,
#    'duration_ms': 243466,
#    'external_ids': {'isrc': 'USATO1400854'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7Gz1adaLeIHNOqJPvfnncD'},
#    'href': 'https://api.spotify.com/v1/tracks/7Gz1adaLeIHNOqJPvfnncD',
#    'id': '7Gz1adaLeIHNOqJPvfnncD',
#    'name': 'Gimme All Your Love',
#    'popularity': 0,
#    'uri': 'spotify:track:7Gz1adaLeIHNOqJPvfnncD',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-07-22T19:07:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/4svLfrPPk2npPVuI4kXPYg',
#     'id': '4svLfrPPk2npPVuI4kXPYg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27369101a9ff9d0653a753eab10',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0269101a9ff9d0653a753eab10',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485169101a9ff9d0653a753eab10',
#       'width': 64}],
#     'name': 'Coming Home',
#     'release_date': '2015-06-15',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4svLfrPPk2npPVuI4kXPYg',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qnGvpP8Yth1AqSBMqON5x'},
#       'href': 'https://api.spotify.com/v1/artists/3qnGvpP8Yth1AqSBMqON5x',
#       'id': '3qnGvpP8Yth1AqSBMqON5x',
#       'name': 'Leon Bridges',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qnGvpP8Yth1AqSBMqON5x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4svLfrPPk2npPVuI4kXPYg'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qnGvpP8Yth1AqSBMqON5x'},
#      'href': 'https://api.spotify.com/v1/artists/3qnGvpP8Yth1AqSBMqON5x',
#      'id': '3qnGvpP8Yth1AqSBMqON5x',
#      'name': 'Leon Bridges',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qnGvpP8Yth1AqSBMqON5x'}],
#    'disc_number': 1,
#    'track_number': 10,
#    'duration_ms': 238560,
#    'external_ids': {'isrc': 'USQX91500482'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0NeJjNlprGfZpeX2LQuN6c'},
#    'href': 'https://api.spotify.com/v1/tracks/0NeJjNlprGfZpeX2LQuN6c',
#    'id': '0NeJjNlprGfZpeX2LQuN6c',
#    'name': 'River',
#    'popularity': 1,
#    'uri': 'spotify:track:0NeJjNlprGfZpeX2LQuN6c',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-06T02:44:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5JPUCM3RuyqZpCxWnJ71Cs',
#     'id': '5JPUCM3RuyqZpCxWnJ71Cs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736dda58147ca7e3f7e5e3ee66',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026dda58147ca7e3f7e5e3ee66',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516dda58147ca7e3f7e5e3ee66',
#       'width': 64}],
#     'name': 'Need Your Light',
#     'release_date': '2016-02-19',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5JPUCM3RuyqZpCxWnJ71Cs',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FIrstf3kHEg3zBOyLpvxD'},
#       'href': 'https://api.spotify.com/v1/artists/6FIrstf3kHEg3zBOyLpvxD',
#       'id': '6FIrstf3kHEg3zBOyLpvxD',
#       'name': 'Ra Ra Riot',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FIrstf3kHEg3zBOyLpvxD'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5JPUCM3RuyqZpCxWnJ71Cs'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FIrstf3kHEg3zBOyLpvxD'},
#      'href': 'https://api.spotify.com/v1/artists/6FIrstf3kHEg3zBOyLpvxD',
#      'id': '6FIrstf3kHEg3zBOyLpvxD',
#      'name': 'Ra Ra Riot',
#      'type': 'artist',
#      'uri': 'spotify:artist:6FIrstf3kHEg3zBOyLpvxD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/04XggbrM51GcFPTxBYtRXT'},
#      'href': 'https://api.spotify.com/v1/artists/04XggbrM51GcFPTxBYtRXT',
#      'id': '04XggbrM51GcFPTxBYtRXT',
#      'name': 'Rostam',
#      'type': 'artist',
#      'uri': 'spotify:artist:04XggbrM51GcFPTxBYtRXT'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 280333,
#    'external_ids': {'isrc': 'USBS51500123'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1spp1NXsz4rHcVaJhhndKa'},
#    'href': 'https://api.spotify.com/v1/tracks/1spp1NXsz4rHcVaJhhndKa',
#    'id': '1spp1NXsz4rHcVaJhhndKa',
#    'name': 'Water',
#    'popularity': 0,
#    'uri': 'spotify:track:1spp1NXsz4rHcVaJhhndKa',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-06T03:05:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6FIFqclBriPCb0SjWDaHIk',
#     'id': '6FIFqclBriPCb0SjWDaHIk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f5819f138439b3ac881a2a6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f5819f138439b3ac881a2a6b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f5819f138439b3ac881a2a6b',
#       'width': 64}],
#     'name': 'Veckatimest',
#     'release_date': '2009-05-24',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6FIFqclBriPCb0SjWDaHIk',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#       'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#       'id': '2Jv5eshHtLycR6R8KQCdc4',
#       'name': 'Grizzly Bear',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FIFqclBriPCb0SjWDaHIk'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#      'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#      'id': '2Jv5eshHtLycR6R8KQCdc4',
#      'name': 'Grizzly Bear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 243160,
#    'external_ids': {'isrc': 'GBBPW0900065'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0iTpQYzJnYgh7kIxyq8A2O'},
#    'href': 'https://api.spotify.com/v1/tracks/0iTpQYzJnYgh7kIxyq8A2O',
#    'id': '0iTpQYzJnYgh7kIxyq8A2O',
#    'name': 'Two Weeks',
#    'popularity': 4,
#    'uri': 'spotify:track:0iTpQYzJnYgh7kIxyq8A2O',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-10T00:19:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4ZxgR8Pmmvdjy7J8fmTMLp',
#     'id': '4ZxgR8Pmmvdjy7J8fmTMLp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27396cd76b5b987aef5a5a0835a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0296cd76b5b987aef5a5a0835a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485196cd76b5b987aef5a5a0835a',
#       'width': 64}],
#     'name': 'Love Like This',
#     'release_date': '2014-11-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4ZxgR8Pmmvdjy7J8fmTMLp',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#       'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#       'id': '2KjAo6wVc9d2WcxdxSArpV',
#       'name': 'RY X',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4ZxgR8Pmmvdjy7J8fmTMLp'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#      'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#      'id': '2KjAo6wVc9d2WcxdxSArpV',
#      'name': 'RY X',
#      'type': 'artist',
#      'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 250701,
#    'external_ids': {'isrc': 'GBDRF1400675'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2FCckttvtgRkQHkeWHer6J'},
#    'href': 'https://api.spotify.com/v1/tracks/2FCckttvtgRkQHkeWHer6J',
#    'id': '2FCckttvtgRkQHkeWHer6J',
#    'name': 'Love Like This',
#    'popularity': 0,
#    'uri': 'spotify:track:2FCckttvtgRkQHkeWHer6J',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-12T17:47:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6FUV3GC6UCMjdSF8Cz5HOP',
#     'id': '6FUV3GC6UCMjdSF8Cz5HOP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735c565c10777093da18ce50fa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025c565c10777093da18ce50fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515c565c10777093da18ce50fa',
#       'width': 64}],
#     'name': 'Dearly Departed (Live at Pandora)',
#     'release_date': '2014-03-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6FUV3GC6UCMjdSF8Cz5HOP',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1fZpYWNWdL5Z3wrDtISFUH'},
#       'href': 'https://api.spotify.com/v1/artists/1fZpYWNWdL5Z3wrDtISFUH',
#       'id': '1fZpYWNWdL5Z3wrDtISFUH',
#       'name': 'Shakey Graves',
#       'type': 'artist',
#       'uri': 'spotify:artist:1fZpYWNWdL5Z3wrDtISFUH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FUV3GC6UCMjdSF8Cz5HOP'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1fZpYWNWdL5Z3wrDtISFUH'},
#      'href': 'https://api.spotify.com/v1/artists/1fZpYWNWdL5Z3wrDtISFUH',
#      'id': '1fZpYWNWdL5Z3wrDtISFUH',
#      'name': 'Shakey Graves',
#      'type': 'artist',
#      'uri': 'spotify:artist:1fZpYWNWdL5Z3wrDtISFUH'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 205388,
#    'external_ids': {'isrc': 'USDMG1578501'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Eb2xUDo5T3q6gNTpbZVDB'},
#    'href': 'https://api.spotify.com/v1/tracks/1Eb2xUDo5T3q6gNTpbZVDB',
#    'id': '1Eb2xUDo5T3q6gNTpbZVDB',
#    'name': 'Dearly Departed (Live at Pandora)',
#    'popularity': 0,
#    'uri': 'spotify:track:1Eb2xUDo5T3q6gNTpbZVDB',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-12T18:26:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 12,
#    'duration_ms': 233320,
#    'external_ids': {'isrc': 'USATO1400861'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7GdSvJ1lnSYelQzd0Gv4Fs'},
#    'href': 'https://api.spotify.com/v1/tracks/7GdSvJ1lnSYelQzd0Gv4Fs',
#    'id': '7GdSvJ1lnSYelQzd0Gv4Fs',
#    'name': 'Over My Head',
#    'popularity': 0,
#    'uri': 'spotify:track:7GdSvJ1lnSYelQzd0Gv4Fs',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-10-06T05:31:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1cumevQhD4JVTmpinALC1j',
#     'id': '1cumevQhD4JVTmpinALC1j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730556ca11aec1e008688a2cbb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020556ca11aec1e008688a2cbb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510556ca11aec1e008688a2cbb',
#       'width': 64}],
#     'name': "Baby I Don't Know Oh Oh",
#     'release_date': '2017-10-05',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1cumevQhD4JVTmpinALC1j',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#       'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#       'id': '7pXu47GoqSYRajmBCjxdD6',
#       'name': 'Vulfpeck',
#       'type': 'artist',
#       'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1cumevQhD4JVTmpinALC1j'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#      'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#      'id': '7pXu47GoqSYRajmBCjxdD6',
#      'name': 'Vulfpeck',
#      'type': 'artist',
#      'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/54SLl07eCSMFL8u2H3MwKl'},
#      'href': 'https://api.spotify.com/v1/artists/54SLl07eCSMFL8u2H3MwKl',
#      'id': '54SLl07eCSMFL8u2H3MwKl',
#      'name': 'Charles Jones',
#      'type': 'artist',
#      'uri': 'spotify:artist:54SLl07eCSMFL8u2H3MwKl'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 208954,
#    'external_ids': {'isrc': 'TCADG1740510'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/289kw0163wm0YVcPx6U6AN'},
#    'href': 'https://api.spotify.com/v1/tracks/289kw0163wm0YVcPx6U6AN',
#    'id': '289kw0163wm0YVcPx6U6AN',
#    'name': "Baby I Don't Know Oh Oh",
#    'popularity': 0,
#    'uri': 'spotify:track:289kw0163wm0YVcPx6U6AN',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-10-21T02:37:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/34GiVp9W9v6GjsWLkBp0HS',
#     'id': '34GiVp9W9v6GjsWLkBp0HS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348c0373785bacfb52daebccc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248c0373785bacfb52daebccc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148c0373785bacfb52daebccc',
#       'width': 64}],
#     'name': 'The Dip',
#     'release_date': '2015-04-14',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:34GiVp9W9v6GjsWLkBp0HS',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qFOYqFxPaIwEnffVhJhEn'},
#       'href': 'https://api.spotify.com/v1/artists/2qFOYqFxPaIwEnffVhJhEn',
#       'id': '2qFOYqFxPaIwEnffVhJhEn',
#       'name': 'The Dip',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qFOYqFxPaIwEnffVhJhEn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/34GiVp9W9v6GjsWLkBp0HS'},
#     'total_tracks': 11},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qFOYqFxPaIwEnffVhJhEn'},
#      'href': 'https://api.spotify.com/v1/artists/2qFOYqFxPaIwEnffVhJhEn',
#      'id': '2qFOYqFxPaIwEnffVhJhEn',
#      'name': 'The Dip',
#      'type': 'artist',
#      'uri': 'spotify:artist:2qFOYqFxPaIwEnffVhJhEn'}],
#    'disc_number': 1,
#    'track_number': 7,
#    'duration_ms': 249640,
#    'external_ids': {'isrc': 'TCACF1522244'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6AJDPYNHaDDA7UrFL08L11'},
#    'href': 'https://api.spotify.com/v1/tracks/6AJDPYNHaDDA7UrFL08L11',
#    'id': '6AJDPYNHaDDA7UrFL08L11',
#    'name': 'Working Man',
#    'popularity': 47,
#    'uri': 'spotify:track:6AJDPYNHaDDA7UrFL08L11',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-10-25T04:26:31Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6omkjFYm9jO3Q4sWBzhvVP',
#     'id': '6omkjFYm9jO3Q4sWBzhvVP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273875068df4a764eaab3898d5f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02875068df4a764eaab3898d5f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851875068df4a764eaab3898d5f',
#       'width': 64}],
# ...
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0206eca3ab48b2c3f4d7cad4cc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485106eca3ab48b2c3f4d7cad4cc',
#       'width': 64}],
#     'name': 'Sex Education Original Soundtrack',
#     'release_date': '2020-01-24',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0d5VbUpz8dcGC17Jkm3og4',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#       'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#       'id': '1uR7zoLrSRI8bSL43OZ0GY',
#       'name': 'Ezra Furman',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0d5VbUpz8dcGC17Jkm3og4'},
#     'total_tracks': 19},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#      'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#      'id': '1uR7zoLrSRI8bSL43OZ0GY',
#      'name': 'Ezra Furman',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#    'disc_number': 1,
#    'track_number': 9,
#    'duration_ms': 294966,
#    'external_ids': {'isrc': 'GBBRP1651004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3mTD0EKHUaNU2Cp6PTJGpa'},
#    'href': 'https://api.spotify.com/v1/tracks/3mTD0EKHUaNU2Cp6PTJGpa',
#    'id': '3mTD0EKHUaNU2Cp6PTJGpa',
#    'name': 'I Can Change',
#    'popularity': 37,
#    'uri': 'spotify:track:3mTD0EKHUaNU2Cp6PTJGpa',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-10-06T05:22:15Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5mhk3C0cKun3x8MoIwkukF',
#     'id': '5mhk3C0cKun3x8MoIwkukF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fc7404894640cfa39507a287',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fc7404894640cfa39507a287',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fc7404894640cfa39507a287',
#       'width': 64}],
#     'name': 'Backwards Directions',
#     'release_date': '2022-09-07',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5mhk3C0cKun3x8MoIwkukF',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aej3kKLxSLM0WauTSfZ7k'},
#       'href': 'https://api.spotify.com/v1/artists/4aej3kKLxSLM0WauTSfZ7k',
#       'id': '4aej3kKLxSLM0WauTSfZ7k',
#       'name': 'Abby Sage',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aej3kKLxSLM0WauTSfZ7k'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5mhk3C0cKun3x8MoIwkukF'},
#     'total_tracks': 3},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aej3kKLxSLM0WauTSfZ7k'},
#      'href': 'https://api.spotify.com/v1/artists/4aej3kKLxSLM0WauTSfZ7k',
#      'id': '4aej3kKLxSLM0WauTSfZ7k',
#      'name': 'Abby Sage',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aej3kKLxSLM0WauTSfZ7k'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 187072,
#    'external_ids': {'isrc': 'CAN112200678'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5vbnQr1tWSSREmcIONIUm9'},
#    'href': 'https://api.spotify.com/v1/tracks/5vbnQr1tWSSREmcIONIUm9',
#    'id': '5vbnQr1tWSSREmcIONIUm9',
#    'name': 'Backwards Directions',
#    'popularity': 56,
#    'uri': 'spotify:track:5vbnQr1tWSSREmcIONIUm9',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-10-06T05:24:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/7xS8jyK8mFSGGmONwmuMKu',
#     'id': '7xS8jyK8mFSGGmONwmuMKu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739f9076fbe5fde4f86439fd9e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029f9076fbe5fde4f86439fd9e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519f9076fbe5fde4f86439fd9e',
#       'width': 64}],
#     'name': 'Alexander',
#     'release_date': '2011-03-01',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7xS8jyK8mFSGGmONwmuMKu',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1me05HW5s7TShHra5nN7uE'},
#       'href': 'https://api.spotify.com/v1/artists/1me05HW5s7TShHra5nN7uE',
#       'id': '1me05HW5s7TShHra5nN7uE',
#       'name': 'Alex Ebert',
#       'type': 'artist',
#       'uri': 'spotify:artist:1me05HW5s7TShHra5nN7uE'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7xS8jyK8mFSGGmONwmuMKu'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1me05HW5s7TShHra5nN7uE'},
#      'href': 'https://api.spotify.com/v1/artists/1me05HW5s7TShHra5nN7uE',
#      'id': '1me05HW5s7TShHra5nN7uE',
#      'name': 'Alex Ebert',
#      'type': 'artist',
#      'uri': 'spotify:artist:1me05HW5s7TShHra5nN7uE'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 260920,
#    'external_ids': {'isrc': 'USVR91165603'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4d0YWF2D8hXoyUs8LBkYHg'},
#    'href': 'https://api.spotify.com/v1/tracks/4d0YWF2D8hXoyUs8LBkYHg',
#    'id': '4d0YWF2D8hXoyUs8LBkYHg',
#    'name': 'Truth',
#    'popularity': 9,
#    'uri': 'spotify:track:4d0YWF2D8hXoyUs8LBkYHg',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-11-07T23:54:43Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['CA', 'PR', 'US'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['CA', 'PR', 'US'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6FtOADddclxzVHrpqCe79m',
#     'id': '6FtOADddclxzVHrpqCe79m',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735f36bab2a440874541f1cd88',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025f36bab2a440874541f1cd88',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515f36bab2a440874541f1cd88',
#       'width': 64}],
#     'name': 'Local Valley',
#     'release_date': '2021-09-17',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6FtOADddclxzVHrpqCe79m',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6xrCU6zdcSTsG2hLrojpmI'},
#       'href': 'https://api.spotify.com/v1/artists/6xrCU6zdcSTsG2hLrojpmI',
#       'id': '6xrCU6zdcSTsG2hLrojpmI',
#       'name': 'JosÃ© GonzÃ¡lez',
#       'type': 'artist',
#       'uri': 'spotify:artist:6xrCU6zdcSTsG2hLrojpmI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FtOADddclxzVHrpqCe79m'},
#     'total_tracks': 13},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6xrCU6zdcSTsG2hLrojpmI'},
#      'href': 'https://api.spotify.com/v1/artists/6xrCU6zdcSTsG2hLrojpmI',
#      'id': '6xrCU6zdcSTsG2hLrojpmI',
#      'name': 'JosÃ© GonzÃ¡lez',
#      'type': 'artist',
#      'uri': 'spotify:artist:6xrCU6zdcSTsG2hLrojpmI'}],
#    'disc_number': 1,
#    'track_number': 11,
#    'duration_ms': 188080,
#    'external_ids': {'isrc': 'SEVVX2100111'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ET7YTxeo4tn7BlUGs3t4Y'},
#    'href': 'https://api.spotify.com/v1/tracks/2ET7YTxeo4tn7BlUGs3t4Y',
#    'id': '2ET7YTxeo4tn7BlUGs3t4Y',
#    'name': 'Line Of Fire',
#    'popularity': 43,
#    'uri': 'spotify:track:2ET7YTxeo4tn7BlUGs3t4Y',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-12-12T22:41:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AG',
#     'AR',
#     'BB',
#     'BO',
#     'BR',
#     'BS',
#     'BZ',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'DM',
#     'DO',
#     'EC',
#     'GD',
#     'GT',
#     'GY',
#     'HN',
#     'HT',
#     'JM',
#     'KN',
#     'LC',
#     'MX',
#     'NI',
#     'PA',
#     'PE',
#     'PR',
#     'PY',
#     'SR',
#     'SV',
#     'TT',
#     'US',
#     'UY',
#     'VC',
#     'VE'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PR',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC',
#      'VE'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5vO3cJcNAgBv91ADrMnc8l',
#     'id': '5vO3cJcNAgBv91ADrMnc8l',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a1b3d6ba2509233870c4bf25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a1b3d6ba2509233870c4bf25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a1b3d6ba2509233870c4bf25',
#       'width': 64}],
#     'name': 'All Of Us Flames',
#     'release_date': '2022-08-26',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5vO3cJcNAgBv91ADrMnc8l',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#       'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#       'id': '1uR7zoLrSRI8bSL43OZ0GY',
#       'name': 'Ezra Furman',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vO3cJcNAgBv91ADrMnc8l'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#      'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#      'id': '1uR7zoLrSRI8bSL43OZ0GY',
#      'name': 'Ezra Furman',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 262450,
#    'external_ids': {'isrc': 'GBBRP2100540'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7ofb8SMiE4pDit5ewXNArn'},
#    'href': 'https://api.spotify.com/v1/tracks/7ofb8SMiE4pDit5ewXNArn',
#    'id': '7ofb8SMiE4pDit5ewXNArn',
#    'name': 'Forever In Sunset',
#    'popularity': 27,
#    'uri': 'spotify:track:7ofb8SMiE4pDit5ewXNArn',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
data['tracks']['items']
# Out:
# [{'added_at': '2017-06-23T23:21:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6SIib5yrq0saKy08p2IPrB',
#     'id': '6SIib5yrq0saKy08p2IPrB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c48375f67f100f88207b54bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c48375f67f100f88207b54bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c48375f67f100f88207b54bc',
#       'width': 64}],
#     'name': 'Bad Self Portraits',
#     'release_date': '2014-02-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6SIib5yrq0saKy08p2IPrB',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#       'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#       'id': '3nuc29fYGlQbIrwh4yrNWd',
#       'name': 'Lake Street Dive',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6SIib5yrq0saKy08p2IPrB'},
#     'total_tracks': 11},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#      'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#      'id': '3nuc29fYGlQbIrwh4yrNWd',
#      'name': 'Lake Street Dive',
#      'type': 'artist',
#      'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 215879,
#    'external_ids': {'isrc': 'USFMT1406103'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0NSEZeWHkYCknk1nAVO1Fh'},
#    'href': 'https://api.spotify.com/v1/tracks/0NSEZeWHkYCknk1nAVO1Fh',
#    'id': '0NSEZeWHkYCknk1nAVO1Fh',
#    'name': 'Better Than',
#    'popularity': 0,
#    'uri': 'spotify:track:0NSEZeWHkYCknk1nAVO1Fh',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-21T17:02:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/4g4iUbyDPTz3wCy25Tvivk',
#     'id': '4g4iUbyDPTz3wCy25Tvivk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737a75155128d3e79aa8a30701',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027a75155128d3e79aa8a30701',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517a75155128d3e79aa8a30701',
#       'width': 64}],
#     'name': 'Arrow',
#     'release_date': '2012-02-14',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4g4iUbyDPTz3wCy25Tvivk',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wwMTLM2da1sa2JcJslf8W'},
#       'href': 'https://api.spotify.com/v1/artists/2wwMTLM2da1sa2JcJslf8W',
#       'id': '2wwMTLM2da1sa2JcJslf8W',
#       'name': 'Heartless Bastards',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wwMTLM2da1sa2JcJslf8W'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4g4iUbyDPTz3wCy25Tvivk'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wwMTLM2da1sa2JcJslf8W'},
#      'href': 'https://api.spotify.com/v1/artists/2wwMTLM2da1sa2JcJslf8W',
#      'id': '2wwMTLM2da1sa2JcJslf8W',
#      'name': 'Heartless Bastards',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wwMTLM2da1sa2JcJslf8W'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 308066,
#    'external_ids': {'isrc': 'USBQU1100085'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/17ZnveSDBpG9QtL7zLJNPy'},
#    'href': 'https://api.spotify.com/v1/tracks/17ZnveSDBpG9QtL7zLJNPy',
#    'id': '17ZnveSDBpG9QtL7zLJNPy',
#    'name': 'Only For You',
#    'popularity': 0,
#    'uri': 'spotify:track:17ZnveSDBpG9QtL7zLJNPy',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-12T22:46:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0LyGgFrZFXpRKpgj664Xu7',
#     'id': '0LyGgFrZFXpRKpgj664Xu7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d4d231e11ce86d2a6e6f9414',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d4d231e11ce86d2a6e6f9414',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d4d231e11ce86d2a6e6f9414',
#       'width': 64}],
#     'name': 'Thrill of the Arts',
#     'release_date': '2015-10-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0LyGgFrZFXpRKpgj664Xu7',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#       'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#       'id': '7pXu47GoqSYRajmBCjxdD6',
#       'name': 'Vulfpeck',
#       'type': 'artist',
#       'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0LyGgFrZFXpRKpgj664Xu7'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#      'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#      'id': '7pXu47GoqSYRajmBCjxdD6',
#      'name': 'Vulfpeck',
#      'type': 'artist',
#      'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 181259,
#    'external_ids': {'isrc': 'TCACH1515840'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1DrlLvlYd1FIjNavRm6NdX'},
#    'href': 'https://api.spotify.com/v1/tracks/1DrlLvlYd1FIjNavRm6NdX',
#    'id': '1DrlLvlYd1FIjNavRm6NdX',
#    'name': 'Back Pocket',
#    'popularity': 61,
#    'uri': 'spotify:track:1DrlLvlYd1FIjNavRm6NdX',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:53:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 257920,
#    'external_ids': {'isrc': 'USATO1400852'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/51ggEZWbFP5dMdWjGCDYTk'},
#    'href': 'https://api.spotify.com/v1/tracks/51ggEZWbFP5dMdWjGCDYTk',
#    'id': '51ggEZWbFP5dMdWjGCDYTk',
#    'name': 'Dunes',
#    'popularity': 0,
#    'uri': 'spotify:track:51ggEZWbFP5dMdWjGCDYTk',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T23:13:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5UXWs03dk4KTJioTAqQKWv',
#     'id': '5UXWs03dk4KTJioTAqQKWv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7db380b3e3bf7080007502c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7db380b3e3bf7080007502c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7db380b3e3bf7080007502c',
#       'width': 64}],
#     'name': 'Bahamas is Afie',
#     'release_date': '2014-08-19',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5UXWs03dk4KTJioTAqQKWv',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C50EbCS11M0VbGyH3OfLt'},
#       'href': 'https://api.spotify.com/v1/artists/4C50EbCS11M0VbGyH3OfLt',
#       'id': '4C50EbCS11M0VbGyH3OfLt',
#       'name': 'Bahamas',
#       'type': 'artist',
#       'uri': 'spotify:artist:4C50EbCS11M0VbGyH3OfLt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UXWs03dk4KTJioTAqQKWv'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C50EbCS11M0VbGyH3OfLt'},
#      'href': 'https://api.spotify.com/v1/artists/4C50EbCS11M0VbGyH3OfLt',
#      'id': '4C50EbCS11M0VbGyH3OfLt',
#      'name': 'Bahamas',
#      'type': 'artist',
#      'uri': 'spotify:artist:4C50EbCS11M0VbGyH3OfLt'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 234973,
#    'external_ids': {'isrc': 'USUG11400491'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/40WXqoyOLAAugGmJWZU1FY'},
#    'href': 'https://api.spotify.com/v1/tracks/40WXqoyOLAAugGmJWZU1FY',
#    'id': '40WXqoyOLAAugGmJWZU1FY',
#    'name': 'All The Time',
#    'popularity': 18,
#    'uri': 'spotify:track:40WXqoyOLAAugGmJWZU1FY',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:54:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1dNRrt0QTrQrZnujD7KS4k',
#     'id': '1dNRrt0QTrQrZnujD7KS4k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273101b0c82d0d3d9079b5b3966',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02101b0c82d0d3d9079b5b3966',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851101b0c82d0d3d9079b5b3966',
#       'width': 64}],
#     'name': 'Future People',
#     'release_date': '2015-03-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1dNRrt0QTrQrZnujD7KS4k',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1dNRrt0QTrQrZnujD7KS4k'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 201612,
#    'external_ids': {'isrc': 'USATO1400853'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6p5LBZkLRIeVhbLh0w7EuP'},
#    'href': 'https://api.spotify.com/v1/tracks/6p5LBZkLRIeVhbLh0w7EuP',
#    'id': '6p5LBZkLRIeVhbLh0w7EuP',
#    'name': 'Future People',
#    'popularity': 0,
#    'uri': 'spotify:track:6p5LBZkLRIeVhbLh0w7EuP',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:55:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 232546,
#    'external_ids': {'isrc': 'USATO1400851'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2lrRWbiHPdBicufAqrGN3r'},
#    'href': 'https://api.spotify.com/v1/tracks/2lrRWbiHPdBicufAqrGN3r',
#    'id': '2lrRWbiHPdBicufAqrGN3r',
#    'name': "Don't Wanna Fight",
#    'popularity': 0,
#    'uri': 'spotify:track:2lrRWbiHPdBicufAqrGN3r',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-04-15T00:58:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 5,
#    'duration_ms': 243466,
#    'external_ids': {'isrc': 'USATO1400854'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7Gz1adaLeIHNOqJPvfnncD'},
#    'href': 'https://api.spotify.com/v1/tracks/7Gz1adaLeIHNOqJPvfnncD',
#    'id': '7Gz1adaLeIHNOqJPvfnncD',
#    'name': 'Gimme All Your Love',
#    'popularity': 0,
#    'uri': 'spotify:track:7Gz1adaLeIHNOqJPvfnncD',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-07-22T19:07:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/4svLfrPPk2npPVuI4kXPYg',
#     'id': '4svLfrPPk2npPVuI4kXPYg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27369101a9ff9d0653a753eab10',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0269101a9ff9d0653a753eab10',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485169101a9ff9d0653a753eab10',
#       'width': 64}],
#     'name': 'Coming Home',
#     'release_date': '2015-06-15',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4svLfrPPk2npPVuI4kXPYg',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qnGvpP8Yth1AqSBMqON5x'},
#       'href': 'https://api.spotify.com/v1/artists/3qnGvpP8Yth1AqSBMqON5x',
#       'id': '3qnGvpP8Yth1AqSBMqON5x',
#       'name': 'Leon Bridges',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qnGvpP8Yth1AqSBMqON5x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4svLfrPPk2npPVuI4kXPYg'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qnGvpP8Yth1AqSBMqON5x'},
#      'href': 'https://api.spotify.com/v1/artists/3qnGvpP8Yth1AqSBMqON5x',
#      'id': '3qnGvpP8Yth1AqSBMqON5x',
#      'name': 'Leon Bridges',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qnGvpP8Yth1AqSBMqON5x'}],
#    'disc_number': 1,
#    'track_number': 10,
#    'duration_ms': 238560,
#    'external_ids': {'isrc': 'USQX91500482'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0NeJjNlprGfZpeX2LQuN6c'},
#    'href': 'https://api.spotify.com/v1/tracks/0NeJjNlprGfZpeX2LQuN6c',
#    'id': '0NeJjNlprGfZpeX2LQuN6c',
#    'name': 'River',
#    'popularity': 1,
#    'uri': 'spotify:track:0NeJjNlprGfZpeX2LQuN6c',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-06T02:44:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5JPUCM3RuyqZpCxWnJ71Cs',
#     'id': '5JPUCM3RuyqZpCxWnJ71Cs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736dda58147ca7e3f7e5e3ee66',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026dda58147ca7e3f7e5e3ee66',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516dda58147ca7e3f7e5e3ee66',
#       'width': 64}],
#     'name': 'Need Your Light',
#     'release_date': '2016-02-19',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5JPUCM3RuyqZpCxWnJ71Cs',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FIrstf3kHEg3zBOyLpvxD'},
#       'href': 'https://api.spotify.com/v1/artists/6FIrstf3kHEg3zBOyLpvxD',
#       'id': '6FIrstf3kHEg3zBOyLpvxD',
#       'name': 'Ra Ra Riot',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FIrstf3kHEg3zBOyLpvxD'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5JPUCM3RuyqZpCxWnJ71Cs'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FIrstf3kHEg3zBOyLpvxD'},
#      'href': 'https://api.spotify.com/v1/artists/6FIrstf3kHEg3zBOyLpvxD',
#      'id': '6FIrstf3kHEg3zBOyLpvxD',
#      'name': 'Ra Ra Riot',
#      'type': 'artist',
#      'uri': 'spotify:artist:6FIrstf3kHEg3zBOyLpvxD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/04XggbrM51GcFPTxBYtRXT'},
#      'href': 'https://api.spotify.com/v1/artists/04XggbrM51GcFPTxBYtRXT',
#      'id': '04XggbrM51GcFPTxBYtRXT',
#      'name': 'Rostam',
#      'type': 'artist',
#      'uri': 'spotify:artist:04XggbrM51GcFPTxBYtRXT'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 280333,
#    'external_ids': {'isrc': 'USBS51500123'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1spp1NXsz4rHcVaJhhndKa'},
#    'href': 'https://api.spotify.com/v1/tracks/1spp1NXsz4rHcVaJhhndKa',
#    'id': '1spp1NXsz4rHcVaJhhndKa',
#    'name': 'Water',
#    'popularity': 0,
#    'uri': 'spotify:track:1spp1NXsz4rHcVaJhhndKa',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-06T03:05:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6FIFqclBriPCb0SjWDaHIk',
#     'id': '6FIFqclBriPCb0SjWDaHIk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f5819f138439b3ac881a2a6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f5819f138439b3ac881a2a6b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f5819f138439b3ac881a2a6b',
#       'width': 64}],
#     'name': 'Veckatimest',
#     'release_date': '2009-05-24',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6FIFqclBriPCb0SjWDaHIk',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#       'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#       'id': '2Jv5eshHtLycR6R8KQCdc4',
#       'name': 'Grizzly Bear',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FIFqclBriPCb0SjWDaHIk'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#      'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#      'id': '2Jv5eshHtLycR6R8KQCdc4',
#      'name': 'Grizzly Bear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 243160,
#    'external_ids': {'isrc': 'GBBPW0900065'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0iTpQYzJnYgh7kIxyq8A2O'},
#    'href': 'https://api.spotify.com/v1/tracks/0iTpQYzJnYgh7kIxyq8A2O',
#    'id': '0iTpQYzJnYgh7kIxyq8A2O',
#    'name': 'Two Weeks',
#    'popularity': 4,
#    'uri': 'spotify:track:0iTpQYzJnYgh7kIxyq8A2O',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-10T00:19:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4ZxgR8Pmmvdjy7J8fmTMLp',
#     'id': '4ZxgR8Pmmvdjy7J8fmTMLp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27396cd76b5b987aef5a5a0835a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0296cd76b5b987aef5a5a0835a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485196cd76b5b987aef5a5a0835a',
#       'width': 64}],
#     'name': 'Love Like This',
#     'release_date': '2014-11-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4ZxgR8Pmmvdjy7J8fmTMLp',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#       'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#       'id': '2KjAo6wVc9d2WcxdxSArpV',
#       'name': 'RY X',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4ZxgR8Pmmvdjy7J8fmTMLp'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#      'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#      'id': '2KjAo6wVc9d2WcxdxSArpV',
#      'name': 'RY X',
#      'type': 'artist',
#      'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 250701,
#    'external_ids': {'isrc': 'GBDRF1400675'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2FCckttvtgRkQHkeWHer6J'},
#    'href': 'https://api.spotify.com/v1/tracks/2FCckttvtgRkQHkeWHer6J',
#    'id': '2FCckttvtgRkQHkeWHer6J',
#    'name': 'Love Like This',
#    'popularity': 0,
#    'uri': 'spotify:track:2FCckttvtgRkQHkeWHer6J',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-12T17:47:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6FUV3GC6UCMjdSF8Cz5HOP',
#     'id': '6FUV3GC6UCMjdSF8Cz5HOP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735c565c10777093da18ce50fa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025c565c10777093da18ce50fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515c565c10777093da18ce50fa',
#       'width': 64}],
#     'name': 'Dearly Departed (Live at Pandora)',
#     'release_date': '2014-03-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6FUV3GC6UCMjdSF8Cz5HOP',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1fZpYWNWdL5Z3wrDtISFUH'},
#       'href': 'https://api.spotify.com/v1/artists/1fZpYWNWdL5Z3wrDtISFUH',
#       'id': '1fZpYWNWdL5Z3wrDtISFUH',
#       'name': 'Shakey Graves',
#       'type': 'artist',
#       'uri': 'spotify:artist:1fZpYWNWdL5Z3wrDtISFUH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FUV3GC6UCMjdSF8Cz5HOP'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1fZpYWNWdL5Z3wrDtISFUH'},
#      'href': 'https://api.spotify.com/v1/artists/1fZpYWNWdL5Z3wrDtISFUH',
#      'id': '1fZpYWNWdL5Z3wrDtISFUH',
#      'name': 'Shakey Graves',
#      'type': 'artist',
#      'uri': 'spotify:artist:1fZpYWNWdL5Z3wrDtISFUH'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 205388,
#    'external_ids': {'isrc': 'USDMG1578501'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Eb2xUDo5T3q6gNTpbZVDB'},
#    'href': 'https://api.spotify.com/v1/tracks/1Eb2xUDo5T3q6gNTpbZVDB',
#    'id': '1Eb2xUDo5T3q6gNTpbZVDB',
#    'name': 'Dearly Departed (Live at Pandora)',
#    'popularity': 0,
#    'uri': 'spotify:track:1Eb2xUDo5T3q6gNTpbZVDB',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-09-12T18:26:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6TWqxofcKQaZ9gHI49G36P',
#     'id': '6TWqxofcKQaZ9gHI49G36P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ac1c6d65fc596eeb9234ef2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ac1c6d65fc596eeb9234ef2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ac1c6d65fc596eeb9234ef2',
#       'width': 64}],
#     'name': 'Sound & Color',
#     'release_date': '2015-04-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6TWqxofcKQaZ9gHI49G36P',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TWqxofcKQaZ9gHI49G36P'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
#      'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#    'disc_number': 1,
#    'track_number': 12,
#    'duration_ms': 233320,
#    'external_ids': {'isrc': 'USATO1400861'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7GdSvJ1lnSYelQzd0Gv4Fs'},
#    'href': 'https://api.spotify.com/v1/tracks/7GdSvJ1lnSYelQzd0Gv4Fs',
#    'id': '7GdSvJ1lnSYelQzd0Gv4Fs',
#    'name': 'Over My Head',
#    'popularity': 0,
#    'uri': 'spotify:track:7GdSvJ1lnSYelQzd0Gv4Fs',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-10-06T05:31:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1cumevQhD4JVTmpinALC1j',
#     'id': '1cumevQhD4JVTmpinALC1j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730556ca11aec1e008688a2cbb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020556ca11aec1e008688a2cbb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510556ca11aec1e008688a2cbb',
#       'width': 64}],
#     'name': "Baby I Don't Know Oh Oh",
#     'release_date': '2017-10-05',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1cumevQhD4JVTmpinALC1j',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#       'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#       'id': '7pXu47GoqSYRajmBCjxdD6',
#       'name': 'Vulfpeck',
#       'type': 'artist',
#       'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1cumevQhD4JVTmpinALC1j'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pXu47GoqSYRajmBCjxdD6'},
#      'href': 'https://api.spotify.com/v1/artists/7pXu47GoqSYRajmBCjxdD6',
#      'id': '7pXu47GoqSYRajmBCjxdD6',
#      'name': 'Vulfpeck',
#      'type': 'artist',
#      'uri': 'spotify:artist:7pXu47GoqSYRajmBCjxdD6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/54SLl07eCSMFL8u2H3MwKl'},
#      'href': 'https://api.spotify.com/v1/artists/54SLl07eCSMFL8u2H3MwKl',
#      'id': '54SLl07eCSMFL8u2H3MwKl',
#      'name': 'Charles Jones',
#      'type': 'artist',
#      'uri': 'spotify:artist:54SLl07eCSMFL8u2H3MwKl'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 208954,
#    'external_ids': {'isrc': 'TCADG1740510'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/289kw0163wm0YVcPx6U6AN'},
#    'href': 'https://api.spotify.com/v1/tracks/289kw0163wm0YVcPx6U6AN',
#    'id': '289kw0163wm0YVcPx6U6AN',
#    'name': "Baby I Don't Know Oh Oh",
#    'popularity': 0,
#    'uri': 'spotify:track:289kw0163wm0YVcPx6U6AN',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-10-21T02:37:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/34GiVp9W9v6GjsWLkBp0HS',
#     'id': '34GiVp9W9v6GjsWLkBp0HS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348c0373785bacfb52daebccc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248c0373785bacfb52daebccc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148c0373785bacfb52daebccc',
#       'width': 64}],
#     'name': 'The Dip',
#     'release_date': '2015-04-14',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:34GiVp9W9v6GjsWLkBp0HS',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qFOYqFxPaIwEnffVhJhEn'},
#       'href': 'https://api.spotify.com/v1/artists/2qFOYqFxPaIwEnffVhJhEn',
#       'id': '2qFOYqFxPaIwEnffVhJhEn',
#       'name': 'The Dip',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qFOYqFxPaIwEnffVhJhEn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/34GiVp9W9v6GjsWLkBp0HS'},
#     'total_tracks': 11},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qFOYqFxPaIwEnffVhJhEn'},
#      'href': 'https://api.spotify.com/v1/artists/2qFOYqFxPaIwEnffVhJhEn',
#      'id': '2qFOYqFxPaIwEnffVhJhEn',
#      'name': 'The Dip',
#      'type': 'artist',
#      'uri': 'spotify:artist:2qFOYqFxPaIwEnffVhJhEn'}],
#    'disc_number': 1,
#    'track_number': 7,
#    'duration_ms': 249640,
#    'external_ids': {'isrc': 'TCACF1522244'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6AJDPYNHaDDA7UrFL08L11'},
#    'href': 'https://api.spotify.com/v1/tracks/6AJDPYNHaDDA7UrFL08L11',
#    'id': '6AJDPYNHaDDA7UrFL08L11',
#    'name': 'Working Man',
#    'popularity': 47,
#    'uri': 'spotify:track:6AJDPYNHaDDA7UrFL08L11',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-10-25T04:26:31Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6omkjFYm9jO3Q4sWBzhvVP',
#     'id': '6omkjFYm9jO3Q4sWBzhvVP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273875068df4a764eaab3898d5f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02875068df4a764eaab3898d5f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851875068df4a764eaab3898d5f',
#       'width': 64}],
# ...
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0206eca3ab48b2c3f4d7cad4cc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485106eca3ab48b2c3f4d7cad4cc',
#       'width': 64}],
#     'name': 'Sex Education Original Soundtrack',
#     'release_date': '2020-01-24',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0d5VbUpz8dcGC17Jkm3og4',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#       'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#       'id': '1uR7zoLrSRI8bSL43OZ0GY',
#       'name': 'Ezra Furman',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0d5VbUpz8dcGC17Jkm3og4'},
#     'total_tracks': 19},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#      'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#      'id': '1uR7zoLrSRI8bSL43OZ0GY',
#      'name': 'Ezra Furman',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#    'disc_number': 1,
#    'track_number': 9,
#    'duration_ms': 294966,
#    'external_ids': {'isrc': 'GBBRP1651004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3mTD0EKHUaNU2Cp6PTJGpa'},
#    'href': 'https://api.spotify.com/v1/tracks/3mTD0EKHUaNU2Cp6PTJGpa',
#    'id': '3mTD0EKHUaNU2Cp6PTJGpa',
#    'name': 'I Can Change',
#    'popularity': 37,
#    'uri': 'spotify:track:3mTD0EKHUaNU2Cp6PTJGpa',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-10-06T05:22:15Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5mhk3C0cKun3x8MoIwkukF',
#     'id': '5mhk3C0cKun3x8MoIwkukF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fc7404894640cfa39507a287',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fc7404894640cfa39507a287',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fc7404894640cfa39507a287',
#       'width': 64}],
#     'name': 'Backwards Directions',
#     'release_date': '2022-09-07',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5mhk3C0cKun3x8MoIwkukF',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aej3kKLxSLM0WauTSfZ7k'},
#       'href': 'https://api.spotify.com/v1/artists/4aej3kKLxSLM0WauTSfZ7k',
#       'id': '4aej3kKLxSLM0WauTSfZ7k',
#       'name': 'Abby Sage',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aej3kKLxSLM0WauTSfZ7k'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5mhk3C0cKun3x8MoIwkukF'},
#     'total_tracks': 3},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aej3kKLxSLM0WauTSfZ7k'},
#      'href': 'https://api.spotify.com/v1/artists/4aej3kKLxSLM0WauTSfZ7k',
#      'id': '4aej3kKLxSLM0WauTSfZ7k',
#      'name': 'Abby Sage',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aej3kKLxSLM0WauTSfZ7k'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 187072,
#    'external_ids': {'isrc': 'CAN112200678'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5vbnQr1tWSSREmcIONIUm9'},
#    'href': 'https://api.spotify.com/v1/tracks/5vbnQr1tWSSREmcIONIUm9',
#    'id': '5vbnQr1tWSSREmcIONIUm9',
#    'name': 'Backwards Directions',
#    'popularity': 56,
#    'uri': 'spotify:track:5vbnQr1tWSSREmcIONIUm9',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-10-06T05:24:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/7xS8jyK8mFSGGmONwmuMKu',
#     'id': '7xS8jyK8mFSGGmONwmuMKu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739f9076fbe5fde4f86439fd9e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029f9076fbe5fde4f86439fd9e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519f9076fbe5fde4f86439fd9e',
#       'width': 64}],
#     'name': 'Alexander',
#     'release_date': '2011-03-01',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7xS8jyK8mFSGGmONwmuMKu',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1me05HW5s7TShHra5nN7uE'},
#       'href': 'https://api.spotify.com/v1/artists/1me05HW5s7TShHra5nN7uE',
#       'id': '1me05HW5s7TShHra5nN7uE',
#       'name': 'Alex Ebert',
#       'type': 'artist',
#       'uri': 'spotify:artist:1me05HW5s7TShHra5nN7uE'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7xS8jyK8mFSGGmONwmuMKu'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1me05HW5s7TShHra5nN7uE'},
#      'href': 'https://api.spotify.com/v1/artists/1me05HW5s7TShHra5nN7uE',
#      'id': '1me05HW5s7TShHra5nN7uE',
#      'name': 'Alex Ebert',
#      'type': 'artist',
#      'uri': 'spotify:artist:1me05HW5s7TShHra5nN7uE'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 260920,
#    'external_ids': {'isrc': 'USVR91165603'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4d0YWF2D8hXoyUs8LBkYHg'},
#    'href': 'https://api.spotify.com/v1/tracks/4d0YWF2D8hXoyUs8LBkYHg',
#    'id': '4d0YWF2D8hXoyUs8LBkYHg',
#    'name': 'Truth',
#    'popularity': 9,
#    'uri': 'spotify:track:4d0YWF2D8hXoyUs8LBkYHg',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-11-07T23:54:43Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['CA', 'PR', 'US'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['CA', 'PR', 'US'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6FtOADddclxzVHrpqCe79m',
#     'id': '6FtOADddclxzVHrpqCe79m',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735f36bab2a440874541f1cd88',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025f36bab2a440874541f1cd88',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515f36bab2a440874541f1cd88',
#       'width': 64}],
#     'name': 'Local Valley',
#     'release_date': '2021-09-17',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6FtOADddclxzVHrpqCe79m',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6xrCU6zdcSTsG2hLrojpmI'},
#       'href': 'https://api.spotify.com/v1/artists/6xrCU6zdcSTsG2hLrojpmI',
#       'id': '6xrCU6zdcSTsG2hLrojpmI',
#       'name': 'JosÃ© GonzÃ¡lez',
#       'type': 'artist',
#       'uri': 'spotify:artist:6xrCU6zdcSTsG2hLrojpmI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FtOADddclxzVHrpqCe79m'},
#     'total_tracks': 13},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6xrCU6zdcSTsG2hLrojpmI'},
#      'href': 'https://api.spotify.com/v1/artists/6xrCU6zdcSTsG2hLrojpmI',
#      'id': '6xrCU6zdcSTsG2hLrojpmI',
#      'name': 'JosÃ© GonzÃ¡lez',
#      'type': 'artist',
#      'uri': 'spotify:artist:6xrCU6zdcSTsG2hLrojpmI'}],
#    'disc_number': 1,
#    'track_number': 11,
#    'duration_ms': 188080,
#    'external_ids': {'isrc': 'SEVVX2100111'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ET7YTxeo4tn7BlUGs3t4Y'},
#    'href': 'https://api.spotify.com/v1/tracks/2ET7YTxeo4tn7BlUGs3t4Y',
#    'id': '2ET7YTxeo4tn7BlUGs3t4Y',
#    'name': 'Line Of Fire',
#    'popularity': 43,
#    'uri': 'spotify:track:2ET7YTxeo4tn7BlUGs3t4Y',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-12-12T22:41:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#    'href': 'https://api.spotify.com/v1/users/1225630715',
#    'id': '1225630715',
#    'type': 'user',
#    'uri': 'spotify:user:1225630715'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AG',
#     'AR',
#     'BB',
#     'BO',
#     'BR',
#     'BS',
#     'BZ',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'DM',
#     'DO',
#     'EC',
#     'GD',
#     'GT',
#     'GY',
#     'HN',
#     'HT',
#     'JM',
#     'KN',
#     'LC',
#     'MX',
#     'NI',
#     'PA',
#     'PE',
#     'PR',
#     'PY',
#     'SR',
#     'SV',
#     'TT',
#     'US',
#     'UY',
#     'VC',
#     'VE'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PR',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC',
#      'VE'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5vO3cJcNAgBv91ADrMnc8l',
#     'id': '5vO3cJcNAgBv91ADrMnc8l',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a1b3d6ba2509233870c4bf25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a1b3d6ba2509233870c4bf25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a1b3d6ba2509233870c4bf25',
#       'width': 64}],
#     'name': 'All Of Us Flames',
#     'release_date': '2022-08-26',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5vO3cJcNAgBv91ADrMnc8l',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#       'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#       'id': '1uR7zoLrSRI8bSL43OZ0GY',
#       'name': 'Ezra Furman',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vO3cJcNAgBv91ADrMnc8l'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uR7zoLrSRI8bSL43OZ0GY'},
#      'href': 'https://api.spotify.com/v1/artists/1uR7zoLrSRI8bSL43OZ0GY',
#      'id': '1uR7zoLrSRI8bSL43OZ0GY',
#      'name': 'Ezra Furman',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uR7zoLrSRI8bSL43OZ0GY'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 262450,
#    'external_ids': {'isrc': 'GBBRP2100540'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7ofb8SMiE4pDit5ewXNArn'},
#    'href': 'https://api.spotify.com/v1/tracks/7ofb8SMiE4pDit5ewXNArn',
#    'id': '7ofb8SMiE4pDit5ewXNArn',
#    'name': 'Forever In Sunset',
#    'popularity': 27,
#    'uri': 'spotify:track:7ofb8SMiE4pDit5ewXNArn',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
# to consider: artist, album, realease date, genre, date added

# %%
# decided: genre, artist, bpm, popularity

# %%
len(data['tracks']['items'])
# Out:
# 146

# %%
data['tracks']['items']('release_date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11368\149821525.py in <module>
# ----> 1 data['tracks']['items']('release_date')
#
# TypeError: 'list' object is not callable

# %%
import pandas as pd
import json
import seaborn as sns
jsonFile = json.load(open("vetting_playlist.json"))
 
# Set json data into Pandas DataFrame
df = pd.DataFrame(jsonFile["tracks"])
 
# Output DataFrame
print(df)
# Out:
#                                                   href  \
# 0    https://api.spotify.com/v1/playlists/0bw8158RM...
# 1    https://api.spotify.com/v1/playlists/0bw8158RM...
# 2    https://api.spotify.com/v1/playlists/0bw8158RM...
# 3    https://api.spotify.com/v1/playlists/0bw8158RM...
# 4    https://api.spotify.com/v1/playlists/0bw8158RM...
# ..                                                 ...
# 141  https://api.spotify.com/v1/playlists/0bw8158RM...
# 142  https://api.spotify.com/v1/playlists/0bw8158RM...
# 143  https://api.spotify.com/v1/playlists/0bw8158RM...
# 144  https://api.spotify.com/v1/playlists/0bw8158RM...
# 145  https://api.spotify.com/v1/playlists/0bw8158RM...
#
#                                                  items  limit  \
# 0    {'added_at': '2017-06-23T23:21:59Z', 'added_by...    100
# 1    {'added_at': '2017-04-21T17:02:44Z', 'added_by...    100
# 2    {'added_at': '2017-06-12T22:46:03Z', 'added_by...    100
# 3    {'added_at': '2017-04-15T00:53:05Z', 'added_by...    100
# 4    {'added_at': '2017-06-29T23:13:06Z', 'added_by...    100
# ..                                                 ...    ...
# 141  {'added_at': '2024-07-02T05:22:56Z', 'added_by...    100
# 142  {'added_at': '2024-10-06T05:22:15Z', 'added_by...    100
# 143  {'added_at': '2024-10-06T05:24:37Z', 'added_by...    100
# 144  {'added_at': '2024-11-07T23:54:43Z', 'added_by...    100
# 145  {'added_at': '2024-12-12T22:41:56Z', 'added_by...    100
#
#                                                   next  offset previous  total
# 0    https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 1    https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 2    https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 3    https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 4    https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# ..                                                 ...     ...      ...    ...
# 141  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 142  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 143  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 144  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 145  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
#
# [146 rows x 7 columns]

# %%
import json
with open("vetting_playlist.json", "r", encoding="utf-8") as f:
    try:
        data = json.load(f)
        print("JSON is valid!")
    except json.JSONDecodeError as e:
        print(f"Invalid JSON: {e}")
# Out:
# JSON is valid!

# %%
df["items"].iloc[0]
# Out:
# {'added_at': '2017-06-23T23:21:59Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#   'href': 'https://api.spotify.com/v1/users/1225630715',
#   'id': '1225630715',
#   'type': 'user',
#   'uri': 'spotify:user:1225630715'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': [],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': [],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/6SIib5yrq0saKy08p2IPrB',
#    'id': '6SIib5yrq0saKy08p2IPrB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c48375f67f100f88207b54bc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c48375f67f100f88207b54bc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c48375f67f100f88207b54bc',
#      'width': 64}],
#    'name': 'Bad Self Portraits',
#    'release_date': '2014-02-18',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:6SIib5yrq0saKy08p2IPrB',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#      'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#      'id': '3nuc29fYGlQbIrwh4yrNWd',
#      'name': 'Lake Street Dive',
#      'type': 'artist',
#      'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6SIib5yrq0saKy08p2IPrB'},
#    'total_tracks': 11},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nuc29fYGlQbIrwh4yrNWd'},
#     'href': 'https://api.spotify.com/v1/artists/3nuc29fYGlQbIrwh4yrNWd',
#     'id': '3nuc29fYGlQbIrwh4yrNWd',
#     'name': 'Lake Street Dive',
#     'type': 'artist',
#     'uri': 'spotify:artist:3nuc29fYGlQbIrwh4yrNWd'}],
#   'disc_number': 1,
#   'track_number': 3,
#   'duration_ms': 215879,
#   'external_ids': {'isrc': 'USFMT1406103'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0NSEZeWHkYCknk1nAVO1Fh'},
#   'href': 'https://api.spotify.com/v1/tracks/0NSEZeWHkYCknk1nAVO1Fh',
#   'id': '0NSEZeWHkYCknk1nAVO1Fh',
#   'name': 'Better Than',
#   'popularity': 0,
#   'uri': 'spotify:track:0NSEZeWHkYCknk1nAVO1Fh',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
df[items].info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11368\2757367147.py in <module>
# ----> 1 df[items].info()
#
# NameError: name 'items' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   href      146 non-null    object
#  1   items     146 non-null    object
#  2   limit     146 non-null    int64
#  3   next      146 non-null    object
#  4   offset    146 non-null    int64
#  5   previous  0 non-null      object
#  6   total     146 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.1+ KB

# %%
df.head()
# Out:
#                                                 href  \
# 0  https://api.spotify.com/v1/playlists/0bw8158RM...
# 1  https://api.spotify.com/v1/playlists/0bw8158RM...
# 2  https://api.spotify.com/v1/playlists/0bw8158RM...
# 3  https://api.spotify.com/v1/playlists/0bw8158RM...
# 4  https://api.spotify.com/v1/playlists/0bw8158RM...
#
#                                                items  limit  \
# 0  {'added_at': '2017-06-23T23:21:59Z', 'added_by...    100
# 1  {'added_at': '2017-04-21T17:02:44Z', 'added_by...    100
# 2  {'added_at': '2017-06-12T22:46:03Z', 'added_by...    100
# 3  {'added_at': '2017-04-15T00:53:05Z', 'added_by...    100
# 4  {'added_at': '2017-06-29T23:13:06Z', 'added_by...    100
#
#                                                 next  offset previous  total
# 0  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 1  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 2  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 3  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146
# 4  https://api.spotify.com/v1/playlists/0bw8158RM...       0     None    146

# %%
import pandas as pd

df_expanded = df["items"].apply(pd.json_normalize)

# %%
import json

def extract_track_info(row):
    item = json.loads(row) if isinstance(row, str) else row  # Convert string JSON if necessary
    track_name = item.get("track", {}).get("name", "Unknown")
    artist_name = item.get("track", {}).get("artists", [{}])[0].get("name", "Unknown")
    return pd.Series([track_name, artist_name])

df[["track_name", "artist_name"]] = df["items"].apply(extract_track_info)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   href         146 non-null    object
#  1   items        146 non-null    object
#  2   limit        146 non-null    int64
#  3   next         146 non-null    object
#  4   offset       146 non-null    int64
#  5   previous     0 non-null      object
#  6   total        146 non-null    int64
#  7   track_name   146 non-null    object
#  8   artist_name  146 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 10.4+ KB

# %%
df_expanded.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 146 entries, 0 to 145
# Series name: items
# Non-Null Count  Dtype
# --------------  -----
# 146 non-null    object
# dtypes: object(1)
# memory usage: 1.3+ KB

# %%
df_expanded.head()
# Out:
# 0                   added_at  is_local primary_colo...
# 1                   added_at  is_local primary_colo...
# 2                   added_at  is_local primary_colo...
# 3                   added_at  is_local primary_colo...
# 4                   added_at  is_local primary_colo...
# Name: items, dtype: object

# %%
artists = pd.read_json("artists_0-999.json")

# %%
mpd = pd.read_json("mpd.slice.0-999.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11368\3999359256.py in <module>
# ----> 1 mpd = pd.read_json("mpd.slice.0-999.json")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     610
#     611     with json_reader:
# --> 612         return json_reader.read()
#     613
#     614
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     744                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     745         else:
# --> 746             obj = self._get_object_parser(self.data)
#     747         self.close()
#     748         return obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     766         obj = None
#     767         if typ == "frame":
# --> 768             obj = FrameParser(json, **kwargs).parse()
#     769
#     770         if typ == "series" or obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     878             self._parse_numpy()
#     879         else:
# --> 880             self._parse_no_numpy()
#     881
#     882         if self.obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1130
#    1131         if orient == "columns":
# -> 1132             self.obj = DataFrame(
#    1133                 loads(json, precise_float=self.precise_float), dtype=None
#    1134             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     675
#     676             if have_dicts:
# --> 677                 raise ValueError(
#     678                     "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679                 )
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
artists.head()
# Out:
#                                           2wIVse2owClT7go1WT98tk  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/2...
# followers                       {'href': None, 'total': 2386591}
# genres         [dance pop, hip hop, hip pop, neo soul, pop ra...
# href           https://api.spotify.com/v1/artists/2wIVse2owCl...
# id                                        2wIVse2owClT7go1WT98tk
#
#                                           26dSoYclwsYLMAKD3tpOr4  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/2...
# followers                      {'href': None, 'total': 13836642}
# genres                                          [dance pop, pop]
# href           https://api.spotify.com/v1/artists/26dSoYclwsY...
# id                                        26dSoYclwsYLMAKD3tpOr4
#
#                                           6vWDO969PvNqNYHIOW5v0m  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/6...
# followers                      {'href': None, 'total': 36504075}
# genres                                                [pop, r&b]
# href           https://api.spotify.com/v1/artists/6vWDO969PvN...
# id                                        6vWDO969PvNqNYHIOW5v0m
#
#                                           31TPClRtHm23RisEBtV3X7  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/3...
# followers                      {'href': None, 'total': 13667356}
# genres                                          [dance pop, pop]
# href           https://api.spotify.com/v1/artists/31TPClRtHm2...
# id                                        31TPClRtHm23RisEBtV3X7
#
#                                           5EvFsr3kj42KNv97ZEnqij  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/5...
# followers                       {'href': None, 'total': 2099287}
# genres                                  [pop rap, reggae fusion]
# href           https://api.spotify.com/v1/artists/5EvFsr3kj42...
# id                                        5EvFsr3kj42KNv97ZEnqij
#
#                                           23zg3TcAtWQy7J6upgbUnj  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/2...
# followers                      {'href': None, 'total': 10974183}
# genres         [atl hip hop, contemporary r&b, dance pop, pop...
# href           https://api.spotify.com/v1/artists/23zg3TcAtWQ...
# id                                        23zg3TcAtWQy7J6upgbUnj
#
#                                           6wPhSqRtPu1UhRCDX5yaDJ  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/6...
# followers                       {'href': None, 'total': 5502730}
# genres                              [dance pop, girl group, pop]
# href           https://api.spotify.com/v1/artists/6wPhSqRtPu1...
# id                                        6wPhSqRtPu1UhRCDX5yaDJ
#
#                                           1Y8cdNmUJH7yBTd9yOvr5i  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/1...
# followers                       {'href': None, 'total': 6932798}
# genres         [dance pop, girl group, pop, r&b, urban contem...
# href           https://api.spotify.com/v1/artists/1Y8cdNmUJH7...
# id                                        1Y8cdNmUJH7yBTd9yOvr5i
#
#                                           1G9G7WwrXka3Z1r7aIDjI7  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/1...
# followers                       {'href': None, 'total': 2518660}
# genres         [atl hip hop, dirty south rap, hip hop, old sc...
# href           https://api.spotify.com/v1/artists/1G9G7WwrXka...
# id                                        1G9G7WwrXka3Z1r7aIDjI7
#
#                                           2jw70GZXlAI8QzWeY2bgRc  ...  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/2...  ...
# followers                       {'href': None, 'total': 3717288}  ...
# genres            [canadian latin, canadian pop, dance pop, pop]  ...
# href           https://api.spotify.com/v1/artists/2jw70GZXlAI...  ...
# id                                        2jw70GZXlAI8QzWeY2bgRc  ...
#
#                                           5xxkw4ElO0WX3v4i1W5kAQ  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/5...
# followers                         {'href': None, 'total': 30404}
# genres                                 [irish singer-songwriter]
# href           https://api.spotify.com/v1/artists/5xxkw4ElO0W...
# id                                        5xxkw4ElO0WX3v4i1W5kAQ
#
#                                           1llFhhYvVi6kC2bfKoPw2k  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/1...
# followers                         {'href': None, 'total': 40111}
# genres                                         [cleveland indie]
# href           https://api.spotify.com/v1/artists/1llFhhYvVi6...
# id                                        1llFhhYvVi6kC2bfKoPw2k
#
#                                           70bIIPbBQeaFzRrIfahMEM  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/7...
# followers                         {'href': None, 'total': 11074}
# genres                                                        []
# href           https://api.spotify.com/v1/artists/70bIIPbBQea...
# id                                        70bIIPbBQeaFzRrIfahMEM
#
#                                           3jBjP8GvB5zigSypIcs0pW  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/3...
# followers                          {'href': None, 'total': 1797}
# genres                                                        []
# href           https://api.spotify.com/v1/artists/3jBjP8GvB5z...
# id                                        3jBjP8GvB5zigSypIcs0pW
#
#                                           6gySlC6ptVBqnzwrMFUDX0  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/6...
# followers                           {'href': None, 'total': 780}
# genres                                                        []
# href           https://api.spotify.com/v1/artists/6gySlC6ptVB...
# id                                        6gySlC6ptVBqnzwrMFUDX0
#
#                                           04BsVprJtIhl2C4fgPEz4W  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/0...
# followers                         {'href': None, 'total': 17366}
# genres                                                        []
# href           https://api.spotify.com/v1/artists/04BsVprJtIh...
# id                                        04BsVprJtIhl2C4fgPEz4W
#
#                                           5HCypjplgh5uQezvBpOfXN  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/5...
# followers                          {'href': None, 'total': 5693}
# genres                                             [channel pop]
# href           https://api.spotify.com/v1/artists/5HCypjplgh5...
# id                                        5HCypjplgh5uQezvBpOfXN
#
#                                           1r2kTJ27zuaEoXasQT5NDd  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/1...
# followers                          {'href': None, 'total': 2168}
# genres                                                        []
# href           https://api.spotify.com/v1/artists/1r2kTJ27zua...
# id                                        1r2kTJ27zuaEoXasQT5NDd
#
#                                           0sHN89qak07mnug3LVVjzP  \
# external_urls  {'spotify': 'https://open.spotify.com/artist/0...
# followers                         {'href': None, 'total': 16658}
# genres                                          [australian r&b]
# href           https://api.spotify.com/v1/artists/0sHN89qak07...
# id                                        0sHN89qak07mnug3LVVjzP
#
#                                           77bNdkKYBBmc30CisCA6tE
# external_urls  {'spotify': 'https://open.spotify.com/artist/7...
# followers                           {'href': None, 'total': 216}
# genres                                                        []
# href           https://api.spotify.com/v1/artists/77bNdkKYBBm...
# id                                        77bNdkKYBBmc30CisCA6tE
#
# [5 rows x 9723 columns]

# %%
df[items].info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11368\2757367147.py in <module>
# ----> 1 df[items].info()
#
# NameError: name 'items' is not defined

# %%
data.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
data['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
data['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
data['tracks'] ['items'][0]['track'].keys()
# Out:
# dict_keys(['preview_url', 'available_markets', 'explicit', 'type', 'episode', 'track', 'album', 'artists', 'disc_number', 'track_number', 'duration_ms', 'external_ids', 'external_urls', 'href', 'id', 'name', 'popularity', 'uri', 'is_local'])

# %%
data['tracks']['items'][0]['track'] ['artists'] [0].keys()
# Out:
# dict_keys(['external_urls', 'href', 'id', 'name', 'type', 'uri'])

# %%
data['tracks'] ['items'][0]['track'] ['artists'][0]['id']
# Out:
# '3nuc29fYGlQbIrwh4yrNWd'

# %%
artist_ids = []

for item in data['tracks']['items']:
    for artist in item['track']['artists']:
        artist_ids.append(artist['id'])

# Remove duplicates if needed
artist_ids = list(set(artist_ids))

print(artist_ids)
# Out:
# ['5QdyldG4Fl4TPiOIeMNpBZ', '3x8FbPjh2Qz55XMdE2Yalj', '3TDPiKzbGXppI5fO7JRtvq', '5xeBMeW0YzWIXSVzAxhM8O', '1QAJqy2dA3ihHBFIHRphZj', '3pIGm1omCcHIb1juBNHspg', '099toTcKJoywTosZr2hHjy', '3qnGvpP8Yth1AqSBMqON5x', '26T3LtbuGT1Fu9m0eRq5X3', '2TwOrUcYnAlIiKmVQkkoSZ', '1yAwtBaoHLEDWAnWR87hBT', '4aej3kKLxSLM0WauTSfZ7k', '0BNz24TKUn8Ov1ApFkLzA1', '0QJIPDAEDILuo8AIq3pMuU', '2Jv5eshHtLycR6R8KQCdc4', '1fZpYWNWdL5Z3wrDtISFUH', '16eRpMNXSQ15wuJoeqguaB', '0K1q0nXQ8is36PzOKAMbNe', '4htjQW3lgIwL6fEJlTOez4', '57vWImR43h4CaDao012Ofp', '066X20Nz7iquqkkCW6Jxy6', '62sC6lUEWRjbFqXpMmOk4G', '3kzwYV3OCB010YfXMF0Avt', '3NqV2DJoAWsjl787bWaHW7', '57kIMCLPgkzQlXjblX7XXP', '5Wabl1lPdNOeIn0SQ5A1mp', '3qYfqdVwX0fil71onLpLkh', '6P5NO5hzJbuOqSdyPB7SJM', '3uOCouLFR4bVx0XeiQJSbl', '0qraFJK6boYSp4ZMMX4PzG', '4C50EbCS11M0VbGyH3OfLt', '12fRkVfO2fUsz1QHgDAG3g', '5cVeSOiS002MF1uiUFOPV5', '6mKqFxGMS5TGDZI3XkT5Rt', '7HcipAIJatVGT4U6HQrnFW', '1xVWSPiw5B0OduIC0DSu3V', '6pmxr66tMAePxzOLfjGNcX', '0P29FQ49qIoK4mJxDJZC7M', '2KjAo6wVc9d2WcxdxSArpV', '6FIrstf3kHEg3zBOyLpvxD', '5dpLK5cD7FwWyDKv4qbodS', '4gzpq5DPGxSnKTe4SA8HAU', '16GcWuvvybAoaHr0NqT8Eh', '2Tz1DTzVJ5Gyh8ZwVr6ekU', '7pXu47GoqSYRajmBCjxdD6', '2eam0iDomRHGBypaDQLwWI', '1uR7zoLrSRI8bSL43OZ0GY', '1X88xrhEvsoUjJ6EUHwiWF', '5W10uJRsbt9bROJDKoI1Wn', '2qFOYqFxPaIwEnffVhJhEn', '1jwOuEBcOKq0BeudSarbEM', '6xrCU6zdcSTsG2hLrojpmI', '2n6FviARgtjjimZXu18uRM', '3kjuyTCjPG1WMFCiyc5IuB', '4uSftVc3FPWe6RJuMZNEe9', '1jSaZgaKHmgc7VTgML528r', '2kGBy2WHvF0VdZyqiVCkDT', '0epOFNiUfyON9EYx7Tpr6V', '1e16kiJQtCTveTl7TQnkFN', '04XggbrM51GcFPTxBYtRXT', '4LG4Bs1Gadht7TCrMytQUO', '7bPs6jf983f0bjRAt1yxDM', '2HSEdXKVq1WWtBbsIeNjRX', '1lGRK7KK1IuflIyNSE9R3M', '5LfGQac0EIXyAN8aUwmNAQ', '5Z3IWpvwOvoaWodujHw7xh', '574ERIqzZ5yZU9JhIf3Ysf', '4bx914GWsNvshDzfYNSKjY', '75dQReiBOHN37fQgWQrIAJ', '6GpcBKNmZDIrRzYkPJu7Wd', '5oVU37Ru65xPHl7dJG7gR9', '38zTZcuN7nFvVJ6auhc6V3', '6qyi8X6MdP1lu6B1K6yh3h', '4mLJ3XfOM5FPjSAWdQ2Jk7', '6JSybS5o47NUTNFQauvxUY', '5BvJzeQpmsdsFp4HGUYUEx', '07D1Bjaof0NFlU32KXiqUP', '54SLl07eCSMFL8u2H3MwKl', '4frXpPxQQZwbCu3eTGnZEw', '09hVIj6vWgoCDtT03h8ZCa', '4Z8W4fKeB5YxbusRsdQVPb', '3nuc29fYGlQbIrwh4yrNWd', '0CDUUM6KNRvgBFYIbWxJwV', '2mVVjNmdjXZZDvhgQWiakk', '4EVpmkEwrLYEg6jIsiPMIb', '5VF0YkVLeVD4ytyiyVSIiF', '58XGUNsRNu3cVOIOYk5chx', '2wwMTLM2da1sa2JcJslf8W', '6YWdHD3R863Apw1hkx3BwC', '485p3wnGrCQ5gskO6IuQ1j', '0hk8VgR64voU5ueK96W2DI', '1me05HW5s7TShHra5nN7uE', '6jlWj6y00bMQt8XoKuCjyZ', '2uYWxilOVlUdk4oV9DvwqK', '2ooIqOf4X2uz4mMptXCtie', '0kgnPJElpccT4mc6IMZ653', '3lmR0qMiGuoIF9UC54egcG', '5INjqkS1o8h1imAzPqGZBb', '2ueoLVCXQ948OfhVvAy3Nn']

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = "your_client_id"
CLIENT_SECRET = "your_client_secret"

track_id = "TRACK_ID"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))

track_data = sp.track(track_id)

artist_ids = []

for artist in track_data["artists"]:
    artist_ids.append(artist["id"])

artists_data = sp.artists(artist_ids)

genres = []

for artist in artists_data["artists"]:
    genres += artist["genres"]

# genres = set(genres) # removes duplicates

print(genres)

# %%
# !pip install spotipy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = "b6286c7ed787435494bb4c28b2a6c57a"
CLIENT_SECRET = "7045aab08c5a425b9434bd8a0ef187f2"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))

artists_data = sp.artists(artist_ids)

genres = []

for artist in artists_data["artists"]:
    genres += artist["genres"]

# genres = set(genres) # removes duplicates

print(genres)
# Out:
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: None
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spotipy in c:\users\enichol\appdata\roaming\python\python39\site-packages (2.25.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\enichol\appdata\roaming\python\python39\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from spotipy) (1.26.11)
# Requirement already satisfied: async-timeout>=4.0.3 in c:\users\enichol\appdata\roaming\python\python39\site-packages (from redis>=3.5.3->spotipy) (5.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: None
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: None
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: None
# ERROR:spotipy.client:Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877             log.debug("Retry: %s", url)
# --> 878             return self.urlopen(
#     879                 method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877             log.debug("Retry: %s", url)
# --> 878             return self.urlopen(
#     879                 method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877             log.debug("Retry: %s", url)
# --> 878             return self.urlopen(
#     879                 method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867             try:
# --> 868                 retries = retries.increment(method, url, response=response, _pool=self)
#     869             except MaxRetryError:
#
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\util.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     169                                 f"Retry will occur after: {retry_header}")
# --> 170         return super().increment(method,
#     171                                  url,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/artists/?ids=5QdyldG4Fl4TPiOIeMNpBZ,3x8FbPjh2Qz55XMdE2Yalj,3TDPiKzbGXppI5fO7JRtvq,5xeBMeW0YzWIXSVzAxhM8O,1QAJqy2dA3ihHBFIHRphZj,3pIGm1omCcHIb1juBNHspg,099toTcKJoywTosZr2hHjy,3qnGvpP8Yth1AqSBMqON5x,26T3LtbuGT1Fu9m0eRq5X3,2TwOrUcYnAlIiKmVQkkoSZ,1yAwtBaoHLEDWAnWR87hBT,4aej3kKLxSLM0WauTSfZ7k,0BNz24TKUn8Ov1ApFkLzA1,0QJIPDAEDILuo8AIq3pMuU,2Jv5eshHtLycR6R8KQCdc4,1fZpYWNWdL5Z3wrDtISFUH,16eRpMNXSQ15wuJoeqguaB,0K1q0nXQ8is36PzOKAMbNe,4htjQW3lgIwL6fEJlTOez4,57vWImR43h4CaDao012Ofp,066X20Nz7iquqkkCW6Jxy6,62sC6lUEWRjbFqXpMmOk4G,3kzwYV3OCB010YfXMF0Avt,3NqV2DJoAWsjl787bWaHW7,57kIMCLPgkzQlXjblX7XXP,5Wabl1lPdNOeIn0SQ5A1mp,3qYfqdVwX0fil71onLpLkh,6P5NO5hzJbuOqSdyPB7SJM,3uOCouLFR4bVx0XeiQJSbl,0qraFJK6boYSp4ZMMX4PzG,4C50EbCS11M0VbGyH3OfLt,12fRkVfO2fUsz1QHgDAG3g,5cVeSOiS002MF1uiUFOPV5,6mKqFxGMS5TGDZI3XkT5Rt,7HcipAIJatVGT4U6HQrnFW,1xVWSPiw5B0OduIC0DSu3V,6pmxr66tMAePxzOLfjGNcX,0P29FQ49qIoK4mJxDJZC7M,2KjAo6wVc9d2WcxdxSArpV,6FIrstf3kHEg3zBOyLpvxD,5dpLK5cD7FwWyDKv4qbodS,4gzpq5DPGxSnKTe4SA8HAU,16GcWuvvybAoaHr0NqT8Eh,2Tz1DTzVJ5Gyh8ZwVr6ekU,7pXu47GoqSYRajmBCjxdD6,2eam0iDomRHGBypaDQLwWI,1uR7zoLrSRI8bSL43OZ0GY,1X88xrhEvsoUjJ6EUHwiWF,5W10uJRsbt9bROJDKoI1Wn,2qFOYqFxPaIwEnffVhJhEn,1jwOuEBcOKq0BeudSarbEM,6xrCU6zdcSTsG2hLrojpmI,2n6FviARgtjjimZXu18uRM,3kjuyTCjPG1WMFCiyc5IuB,4uSftVc3FPWe6RJuMZNEe9,1jSaZgaKHmgc7VTgML528r,2kGBy2WHvF0VdZyqiVCkDT,0epOFNiUfyON9EYx7Tpr6V,1e16kiJQtCTveTl7TQnkFN,04XggbrM51GcFPTxBYtRXT,4LG4Bs1Gadht7TCrMytQUO,7bPs6jf983f0bjRAt1yxDM,2HSEdXKVq1WWtBbsIeNjRX,1lGRK7KK1IuflIyNSE9R3M,5LfGQac0EIXyAN8aUwmNAQ,5Z3IWpvwOvoaWodujHw7xh,574ERIqzZ5yZU9JhIf3Ysf,4bx914GWsNvshDzfYNSKjY,75dQReiBOHN37fQgWQrIAJ,6GpcBKNmZDIrRzYkPJu7Wd,5oVU37Ru65xPHl7dJG7gR9,38zTZcuN7nFvVJ6auhc6V3,6qyi8X6MdP1lu6B1K6yh3h,4mLJ3XfOM5FPjSAWdQ2Jk7,6JSybS5o47NUTNFQauvxUY,5BvJzeQpmsdsFp4HGUYUEx,07D1Bjaof0NFlU32KXiqUP,54SLl07eCSMFL8u2H3MwKl,4frXpPxQQZwbCu3eTGnZEw,09hVIj6vWgoCDtT03h8ZCa,4Z8W4fKeB5YxbusRsdQVPb,3nuc29fYGlQbIrwh4yrNWd,0CDUUM6KNRvgBFYIbWxJwV,2mVVjNmdjXZZDvhgQWiakk,4EVpmkEwrLYEg6jIsiPMIb,5VF0YkVLeVD4ytyiyVSIiF,58XGUNsRNu3cVOIOYk5chx,2wwMTLM2da1sa2JcJslf8W,6YWdHD3R863Apw1hkx3BwC,485p3wnGrCQ5gskO6IuQ1j,0hk8VgR64voU5ueK96W2DI,1me05HW5s7TShHra5nN7uE,6jlWj6y00bMQt8XoKuCjyZ,2uYWxilOVlUdk4oV9DvwqK,2ooIqOf4X2uz4mMptXCtie,0kgnPJElpccT4mc6IMZ653,3lmR0qMiGuoIF9UC54egcG,5INjqkS1o8h1imAzPqGZBb,2ueoLVCXQ948OfhVvAy3Nn (Caused by ResponseError('too many 502 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     269         try:
# --> 270             response = self._session.request(
#     271                 method, url, headers=headers, proxies=self.proxies,
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     555             if isinstance(e.reason, ResponseError):
# --> 556                 raise RetryError(e, request=request)
#     557
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/artists/?ids=5QdyldG4Fl4TPiOIeMNpBZ,3x8FbPjh2Qz55XMdE2Yalj,3TDPiKzbGXppI5fO7JRtvq,5xeBMeW0YzWIXSVzAxhM8O,1QAJqy2dA3ihHBFIHRphZj,3pIGm1omCcHIb1juBNHspg,099toTcKJoywTosZr2hHjy,3qnGvpP8Yth1AqSBMqON5x,26T3LtbuGT1Fu9m0eRq5X3,2TwOrUcYnAlIiKmVQkkoSZ,1yAwtBaoHLEDWAnWR87hBT,4aej3kKLxSLM0WauTSfZ7k,0BNz24TKUn8Ov1ApFkLzA1,0QJIPDAEDILuo8AIq3pMuU,2Jv5eshHtLycR6R8KQCdc4,1fZpYWNWdL5Z3wrDtISFUH,16eRpMNXSQ15wuJoeqguaB,0K1q0nXQ8is36PzOKAMbNe,4htjQW3lgIwL6fEJlTOez4,57vWImR43h4CaDao012Ofp,066X20Nz7iquqkkCW6Jxy6,62sC6lUEWRjbFqXpMmOk4G,3kzwYV3OCB010YfXMF0Avt,3NqV2DJoAWsjl787bWaHW7,57kIMCLPgkzQlXjblX7XXP,5Wabl1lPdNOeIn0SQ5A1mp,3qYfqdVwX0fil71onLpLkh,6P5NO5hzJbuOqSdyPB7SJM,3uOCouLFR4bVx0XeiQJSbl,0qraFJK6boYSp4ZMMX4PzG,4C50EbCS11M0VbGyH3OfLt,12fRkVfO2fUsz1QHgDAG3g,5cVeSOiS002MF1uiUFOPV5,6mKqFxGMS5TGDZI3XkT5Rt,7HcipAIJatVGT4U6HQrnFW,1xVWSPiw5B0OduIC0DSu3V,6pmxr66tMAePxzOLfjGNcX,0P29FQ49qIoK4mJxDJZC7M,2KjAo6wVc9d2WcxdxSArpV,6FIrstf3kHEg3zBOyLpvxD,5dpLK5cD7FwWyDKv4qbodS,4gzpq5DPGxSnKTe4SA8HAU,16GcWuvvybAoaHr0NqT8Eh,2Tz1DTzVJ5Gyh8ZwVr6ekU,7pXu47GoqSYRajmBCjxdD6,2eam0iDomRHGBypaDQLwWI,1uR7zoLrSRI8bSL43OZ0GY,1X88xrhEvsoUjJ6EUHwiWF,5W10uJRsbt9bROJDKoI1Wn,2qFOYqFxPaIwEnffVhJhEn,1jwOuEBcOKq0BeudSarbEM,6xrCU6zdcSTsG2hLrojpmI,2n6FviARgtjjimZXu18uRM,3kjuyTCjPG1WMFCiyc5IuB,4uSftVc3FPWe6RJuMZNEe9,1jSaZgaKHmgc7VTgML528r,2kGBy2WHvF0VdZyqiVCkDT,0epOFNiUfyON9EYx7Tpr6V,1e16kiJQtCTveTl7TQnkFN,04XggbrM51GcFPTxBYtRXT,4LG4Bs1Gadht7TCrMytQUO,7bPs6jf983f0bjRAt1yxDM,2HSEdXKVq1WWtBbsIeNjRX,1lGRK7KK1IuflIyNSE9R3M,5LfGQac0EIXyAN8aUwmNAQ,5Z3IWpvwOvoaWodujHw7xh,574ERIqzZ5yZU9JhIf3Ysf,4bx914GWsNvshDzfYNSKjY,75dQReiBOHN37fQgWQrIAJ,6GpcBKNmZDIrRzYkPJu7Wd,5oVU37Ru65xPHl7dJG7gR9,38zTZcuN7nFvVJ6auhc6V3,6qyi8X6MdP1lu6B1K6yh3h,4mLJ3XfOM5FPjSAWdQ2Jk7,6JSybS5o47NUTNFQauvxUY,5BvJzeQpmsdsFp4HGUYUEx,07D1Bjaof0NFlU32KXiqUP,54SLl07eCSMFL8u2H3MwKl,4frXpPxQQZwbCu3eTGnZEw,09hVIj6vWgoCDtT03h8ZCa,4Z8W4fKeB5YxbusRsdQVPb,3nuc29fYGlQbIrwh4yrNWd,0CDUUM6KNRvgBFYIbWxJwV,2mVVjNmdjXZZDvhgQWiakk,4EVpmkEwrLYEg6jIsiPMIb,5VF0YkVLeVD4ytyiyVSIiF,58XGUNsRNu3cVOIOYk5chx,2wwMTLM2da1sa2JcJslf8W,6YWdHD3R863Apw1hkx3BwC,485p3wnGrCQ5gskO6IuQ1j,0hk8VgR64voU5ueK96W2DI,1me05HW5s7TShHra5nN7uE,6jlWj6y00bMQt8XoKuCjyZ,2uYWxilOVlUdk4oV9DvwqK,2ooIqOf4X2uz4mMptXCtie,0kgnPJElpccT4mc6IMZ653,3lmR0qMiGuoIF9UC54egcG,5INjqkS1o8h1imAzPqGZBb,2ueoLVCXQ948OfhVvAy3Nn (Caused by ResponseError('too many 502 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11368\1361268751.py in <module>
#       9 sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))
#      10
# ---> 11 artists_data = sp.artists(artist_ids)
#      12
#      13 genres = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\client.py in artists(self, artists)
#     404
#     405         tlist = [self._get_id("artist", a) for a in artists]
# --> 406         return self._get("artists/?ids=" + ",".join(tlist))
#     407
#     408     def artist_albums(
#
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     325             kwargs.update(args)
#     326
# --> 327         return self._internal_call("GET", url, payload, kwargs)
#     328
#     329     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\AppData\Roaming\Python\Python39\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     309             except (IndexError, AttributeError):
#     310                 reason = None
# --> 311             raise SpotifyException(
#     312                 429,
#     313                 -1,
#
# SpotifyException: http status: 429, code:-1 - /v1/artists/?ids=5QdyldG4Fl4TPiOIeMNpBZ,3x8FbPjh2Qz55XMdE2Yalj,3TDPiKzbGXppI5fO7JRtvq,5xeBMeW0YzWIXSVzAxhM8O,1QAJqy2dA3ihHBFIHRphZj,3pIGm1omCcHIb1juBNHspg,099toTcKJoywTosZr2hHjy,3qnGvpP8Yth1AqSBMqON5x,26T3LtbuGT1Fu9m0eRq5X3,2TwOrUcYnAlIiKmVQkkoSZ,1yAwtBaoHLEDWAnWR87hBT,4aej3kKLxSLM0WauTSfZ7k,0BNz24TKUn8Ov1ApFkLzA1,0QJIPDAEDILuo8AIq3pMuU,2Jv5eshHtLycR6R8KQCdc4,1fZpYWNWdL5Z3wrDtISFUH,16eRpMNXSQ15wuJoeqguaB,0K1q0nXQ8is36PzOKAMbNe,4htjQW3lgIwL6fEJlTOez4,57vWImR43h4CaDao012Ofp,066X20Nz7iquqkkCW6Jxy6,62sC6lUEWRjbFqXpMmOk4G,3kzwYV3OCB010YfXMF0Avt,3NqV2DJoAWsjl787bWaHW7,57kIMCLPgkzQlXjblX7XXP,5Wabl1lPdNOeIn0SQ5A1mp,3qYfqdVwX0fil71onLpLkh,6P5NO5hzJbuOqSdyPB7SJM,3uOCouLFR4bVx0XeiQJSbl,0qraFJK6boYSp4ZMMX4PzG,4C50EbCS11M0VbGyH3OfLt,12fRkVfO2fUsz1QHgDAG3g,5cVeSOiS002MF1uiUFOPV5,6mKqFxGMS5TGDZI3XkT5Rt,7HcipAIJatVGT4U6HQrnFW,1xVWSPiw5B0OduIC0DSu3V,6pmxr66tMAePxzOLfjGNcX,0P29FQ49qIoK4mJxDJZC7M,2KjAo6wVc9d2WcxdxSArpV,6FIrstf3kHEg3zBOyLpvxD,5dpLK5cD7FwWyDKv4qbodS,4gzpq5DPGxSnKTe4SA8HAU,16GcWuvvybAoaHr0NqT8Eh,2Tz1DTzVJ5Gyh8ZwVr6ekU,7pXu47GoqSYRajmBCjxdD6,2eam0iDomRHGBypaDQLwWI,1uR7zoLrSRI8bSL43OZ0GY,1X88xrhEvsoUjJ6EUHwiWF,5W10uJRsbt9bROJDKoI1Wn,2qFOYqFxPaIwEnffVhJhEn,1jwOuEBcOKq0BeudSarbEM,6xrCU6zdcSTsG2hLrojpmI,2n6FviARgtjjimZXu18uRM,3kjuyTCjPG1WMFCiyc5IuB,4uSftVc3FPWe6RJuMZNEe9,1jSaZgaKHmgc7VTgML528r,2kGBy2WHvF0VdZyqiVCkDT,0epOFNiUfyON9EYx7Tpr6V,1e16kiJQtCTveTl7TQnkFN,04XggbrM51GcFPTxBYtRXT,4LG4Bs1Gadht7TCrMytQUO,7bPs6jf983f0bjRAt1yxDM,2HSEdXKVq1WWtBbsIeNjRX,1lGRK7KK1IuflIyNSE9R3M,5LfGQac0EIXyAN8aUwmNAQ,5Z3IWpvwOvoaWodujHw7xh,574ERIqzZ5yZU9JhIf3Ysf,4bx914GWsNvshDzfYNSKjY,75dQReiBOHN37fQgWQrIAJ,6GpcBKNmZDIrRzYkPJu7Wd,5oVU37Ru65xPHl7dJG7gR9,38zTZcuN7nFvVJ6auhc6V3,6qyi8X6MdP1lu6B1K6yh3h,4mLJ3XfOM5FPjSAWdQ2Jk7,6JSybS5o47NUTNFQauvxUY,5BvJzeQpmsdsFp4HGUYUEx,07D1Bjaof0NFlU32KXiqUP,54SLl07eCSMFL8u2H3MwKl,4frXpPxQQZwbCu3eTGnZEw,09hVIj6vWgoCDtT03h8ZCa,4Z8W4fKeB5YxbusRsdQVPb,3nuc29fYGlQbIrwh4yrNWd,0CDUUM6KNRvgBFYIbWxJwV,2mVVjNmdjXZZDvhgQWiakk,4EVpmkEwrLYEg6jIsiPMIb,5VF0YkVLeVD4ytyiyVSIiF,58XGUNsRNu3cVOIOYk5chx,2wwMTLM2da1sa2JcJslf8W,6YWdHD3R863Apw1hkx3BwC,485p3wnGrCQ5gskO6IuQ1j,0hk8VgR64voU5ueK96W2DI,1me05HW5s7TShHra5nN7uE,6jlWj6y00bMQt8XoKuCjyZ,2uYWxilOVlUdk4oV9DvwqK,2ooIqOf4X2uz4mMptXCtie,0kgnPJElpccT4mc6IMZ653,3lmR0qMiGuoIF9UC54egcG,5INjqkS1o8h1imAzPqGZBb,2ueoLVCXQ948OfhVvAy3Nn:
#  Max Retries, reason: too many 502 error responses

# %%
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from requests.exceptions import ReadTimeout, ConnectionError
from spotipy.exceptions import SpotifyException

# Spotify Authentication
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="YOUR_CLIENT_ID", 
                                                           client_secret="YOUR_CLIENT_SECRET"))

def safe_api_call(func, *args, **kwargs):
    retries = 5  # Maximum retries
    for i in range(retries):
        try:
            return func(*args, **kwargs)
        except SpotifyException as e:
            if e.http_status == 429:  # Rate limit exceeded
                retry_after = int(e.headers.get("Retry-After", 5))  # Default to 5 seconds
                print(f"Rate limit exceeded. Retrying in {retry_after} seconds...")
                time.sleep(retry_after)
            else:
                raise
        except (ReadTimeout, ConnectionError) as e:
            print(f"Connection error: {e}. Retrying in {2**i} seconds...")
            time.sleep(2**i)
    return None

# Example usage
artist_ids = ["5QdyldG4Fl4TPiOIeMNpBZ", "3x8FbPjh2Qz55XMdE2Yalj"]  # Example IDs
artists = safe_api_call(sp.artists, artist_ids)
print(artists)
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5QdyldG4Fl4TPiOIeMNpBZ'}, 'followers': {'href': None, 'total': 1083892}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5QdyldG4Fl4TPiOIeMNpBZ', 'id': '5QdyldG4Fl4TPiOIeMNpBZ', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eba54dfec710033513df46f705', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616100005174a54dfec710033513df46f705', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f178a54dfec710033513df46f705', 'height': 160, 'width': 160}], 'name': 'Big Thief', 'popularity': 69, 'type': 'artist', 'uri': 'spotify:artist:5QdyldG4Fl4TPiOIeMNpBZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3x8FbPjh2Qz55XMdE2Yalj'}, 'followers': {'href': None, 'total': 295496}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3x8FbPjh2Qz55XMdE2Yalj', 'id': '3x8FbPjh2Qz55XMdE2Yalj', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb25936f449f079482efe7f875', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab6761610000517425936f449f079482efe7f875', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f17825936f449f079482efe7f875', 'height': 160, 'width': 160}], 'name': 'Nick Mulvey', 'popularity': 55, 'type': 'artist', 'uri': 'spotify:artist:3x8FbPjh2Qz55XMdE2Yalj'}]}

# %%
CLIENT_ID = "b6286c7ed787435494bb4c28b2a6c57a"
CLIENT_SECRET = "7045aab08c5a425b9434bd8a0ef187f2"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,client_secret=CLIENT_SECRET))

artists_data = safe_api_call(sp.artists, artist_ids)

genres = []

for artist in artists_data["artists"]:
    genres += artist["genres"]

# genres = set(genres) # removes duplicates

print(genres)
# Out:
# []

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.exceptions import SpotifyException
import time
from requests.exceptions import ReadTimeout, ConnectionError

# Spotify API credentials
CLIENT_ID = "b6286c7ed787435494bb4c28b2a6c57a"
CLIENT_SECRET = "7045aab08c5a425b9434bd8a0ef187f2"

# Authenticate with Spotify API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

# List of artist IDs (Replace with actual IDs)
artist_ids = ["0OdUWJ0sBjDrqHygGUXeCF", "1Xyo4u8uXC1ZmMpatF05PJ"]  # Example IDs

# Fetch artist data safely
artists_data = safe_api_call(sp.artists, artist_ids)

# Extract genres safely
genres = []
if artists_data:  # Ensure data was retrieved successfully
    for artist in artists_data.get("artists", []):
        genres.extend(artist.get("genres", []))  # Use extend instead of += for clarity

# Remove duplicates (optional)
genres = list(set(genres))

print(genres)
# Out:
# []

# %%
print("Artists Data:", artists_data)
# Out:
# Artists Data: {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OdUWJ0sBjDrqHygGUXeCF'}, 'followers': {'href': None, 'total': 1030545}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0OdUWJ0sBjDrqHygGUXeCF', 'id': '0OdUWJ0sBjDrqHygGUXeCF', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebde20f1d3bdfc3239a770921c', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616100005174de20f1d3bdfc3239a770921c', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f178de20f1d3bdfc3239a770921c', 'height': 160, 'width': 160}], 'name': 'Band of Horses', 'popularity': 60, 'type': 'artist', 'uri': 'spotify:artist:0OdUWJ0sBjDrqHygGUXeCF'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}, 'followers': {'href': None, 'total': 100540017}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ', 'id': '1Xyo4u8uXC1ZmMpatF05PJ', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb9e528993a2820267b97f6aae', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab676161000051749e528993a2820267b97f6aae', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f1789e528993a2820267b97f6aae', 'height': 160, 'width': 160}], 'name': 'The Weeknd', 'popularity': 97, 'type': 'artist', 'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}]}

# %%
print("Artist IDs Sent:", artist_ids)
# Out:
# Artist IDs Sent: ['0OdUWJ0sBjDrqHygGUXeCF', '1Xyo4u8uXC1ZmMpatF05PJ']

# %%
except SpotifyException as e:
    print(f"Spotify API Error: {e}")
    raise  # This will show the error details
# Out:
#   File "C:\Users\enichol\AppData\Local\Temp\ipykernel_11368\1147109972.py", line 1
#     except SpotifyException as e:
#     ^
# SyntaxError: invalid syntax

# %%
from spotipy.exceptions import SpotifyException

try:
    # Your Spotify-related code here
    genres = []
    for artist in artists_data["artists"]:
        genres += artist["genres"]



except SpotifyException as e:
    print(f"Spotify error occurred: {e}")

print(genres)
# Out:
# []

# %%
artists_data = sp.artists(artist_ids)
print(artists_data)
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OdUWJ0sBjDrqHygGUXeCF'}, 'followers': {'href': None, 'total': 1030545}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0OdUWJ0sBjDrqHygGUXeCF', 'id': '0OdUWJ0sBjDrqHygGUXeCF', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebde20f1d3bdfc3239a770921c', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616100005174de20f1d3bdfc3239a770921c', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f178de20f1d3bdfc3239a770921c', 'height': 160, 'width': 160}], 'name': 'Band of Horses', 'popularity': 60, 'type': 'artist', 'uri': 'spotify:artist:0OdUWJ0sBjDrqHygGUXeCF'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}, 'followers': {'href': None, 'total': 100540017}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ', 'id': '1Xyo4u8uXC1ZmMpatF05PJ', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb9e528993a2820267b97f6aae', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab676161000051749e528993a2820267b97f6aae', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f1789e528993a2820267b97f6aae', 'height': 160, 'width': 160}], 'name': 'The Weeknd', 'popularity': 97, 'type': 'artist', 'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}]}

# %%
def get_token(client_id, client_secret):
    token_url = 'https://accounts.spotify.com/api/token'
    
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    
    data = {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret
    }
    
    response = requests.post(token_url, headers=headers, data=data)
    return response.json()

client_id = "b6286c7ed787435494bb4c28b2a6c57a"
client_secret = "7045aab08c5a425b9434bd8a0ef187f2"
token_response = get_token(client_id, client_secret)
access_token = token_response['access_token']

# %%
headers = {
    'Authorization': 'Bearer ' + access_token
}

# %%
def get_genres(artists):
    genres = []
    # Make request from Spotify API using artist id
    #for art_id in artists['spot_id']:
    for artist_id in artist_ids:
        response = requests.get('https://api.spotify.com/v1/artists/' + artist_id, headers=headers)
        artist_genres = response.json()['genres']
        genres.append(artist_genres)
        
    # Add column of genres to artists dictionary
    artists['genres'] = genres
    return genres

# %%
# artist_ids

# %%
playlist_artists = {
        'name':[],
        'spot_id': []
    }
playlist_genres = get_genres(playlist_artists)

# %%
get_genres(artist_ids)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11368\200987664.py in <module>
# ----> 1 get_genres(artist_ids)
#
# ~\AppData\Local\Temp\ipykernel_11368\3726296573.py in get_genres(artists)
#       9
#      10     # Add column of genres to artists dictionary
# ---> 11     artists['genres'] = genres
#      12     return genres
#
# TypeError: list indices must be integers or slices, not str
